# %%
import os
import pandas as pd
import numpy as np
from warnings import filterwarnings
filterwarnings('ignore')

# %%
from sklearn.model_selection import cross_val_predict
from sklearn.svm import SVR
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_validate
from sklearn.model_selection import LeaveOneOut, KFold, cross_val_score

# %%
from sklearn.metrics import r2_score
from scipy.stats import pearsonr
from scipy.stats import spearmanr
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
output_dir = 'C:\\Users\\MONSTER\\Desktop\\TEZ SON\\CCLE\\OUTPUT3'

# %%
os.chdir(output_dir)

# %%
Drugs = [item1 for item1 in os.listdir() if os.path.isdir(item1)]

# %% [raw]
# Histology_dict = dict()
# Drug_dict = dict()
# IC50_predict = dict()
#
# for histology in Histologies:
#     os.chdir(os.path.join(output_dir_ccle, histology))
#     if len(os.listdir()) > 1:
#         Drugs_ccle = [item1 for item1 in os.listdir() if os.path.isdir(item1)]
#
#         os.chdir(os.path.join(output_dir_gdsc, histology))
#         if len(os.listdir()) > 1:
#             Drugs_gdsc = [item1 for item1 in os.listdir() if os.path.isdir(item1)]
#
#             common_drug_ccle_gdsc = set(Drugs_ccle).intersection(Drugs_gdsc)
#             if len(common_drug_ccle_gdsc) > 0:
#
#                 for drug in common_drug_ccle_gdsc:
#
#                     expression_data = pd.read_csv(os.path.join(output_dir_ccle,histology,drug,drug+" "+histology+" "+"- Expression Data(IC50).tsv"), sep = ",")
#                     gdsc_train_data = pd.read_csv(os.path.join(output_dir_gdsc,histology,drug,drug+" "+histology+" "+"- GDSC Histology Project.tsv"), sep = "\t")
#
#                     if len(expression_data.columns) > 3 and len(expression_data['Cell Line']) > 20 and len(gdsc_train_data['Cell Line']) > 20:
#
#                         x_ccle = expression_data.drop(['Unnamed: 0', 'Cell Line', 'LN_IC50'], axis=1)
#                         y_ccle = expression_data['LN_IC50']
#
#                         x_gdsc_1 = gdsc_train_data.drop(['Cell Line','GDSC\nTissue descriptor 1','LN_IC50','Drug'], axis=1)
#                         y_gdsc = gdsc_train_data['LN_IC50']
#
#                         common_features_ccle_gdsc = set(x_ccle.columns).intersection(x_gdsc_1.columns)
#                         if len(common_features_ccle_gdsc) > 0:
#
#                             features_name = common_features_ccle_gdsc
#                             sample_number_gdsc_drug = len(gdsc_train_data['Cell Line'])
#
#                             x_ccle = x_ccle[list(features_name)]
#                             #y_ccle = boruta_drug_data_ccle['log IC50 (uM)']
#
#                             x_gdsc = x_gdsc_1[list(features_name)]
#                             #y_gdsc = boruta_drug_data_gdsc[drug]
#
#                             features_name_number= len((x_gdsc).columns)
#
#                             x_ccle = np.array(x_ccle)
#                             y_ccle = np.array(y_ccle)
#                             x_gdsc = np.array(x_gdsc)
#                             y_gdsc = np.array(y_gdsc)
#
#
#                             # MODEL OLUŞTURUYORUZ
#
#                             # LOOCV (Leave-One-Out Cross-Validation)
#                             loo = LeaveOneOut()
#                             svr_model = SVR(kernel='rbf')
#                             scores_loocv = cross_val_score(svr_model, x_ccle, y_ccle, cv=loo, scoring='neg_mean_squared_error')
#                             mean_score_loocv = scores_loocv.mean()
#
#                             # k-fold kullanılıyor.
#                             kfold = KFold(n_splits=2, random_state=1, shuffle = True)
#                             scores_kfold = cross_val_score(svr_model, x_ccle, y_ccle, cv=kfold, scoring='neg_mean_squared_error')
#                             mean_score_kfold = scores_kfold.mean()
#
#                             svr_model.fit(x_ccle, y_ccle)
#
#
#                             # Tahmin yapılıyor.
#                             y_gdsc_pred = svr_model.predict(x_gdsc)
#
#                             print(histology)
#                             print(f"\nDrug : SVR is running for {drug}", flush=True)
#
#
#                             r_squared = r2_score(y_gdsc, y_gdsc_pred)
#                             pearson_correlation, p_value_pearsonr = pearsonr(y_gdsc_pred, y_gdsc)
#                             corr_spearmanr, p_value_spearmanr = spearmanr(y_gdsc_pred, y_gdsc)
#                             rmse_val = np.sqrt(mean_squared_error(y_gdsc_pred, y_gdsc))
#
#                             features_name = list(features_name)
#                             result_table_drug = pd.DataFrame({
#                             'Tissue': [histology],
#                             'Drug': [drug],
#                             'R_Square': [r_squared],
#                             'Pearson_Correlation_Train': [pearson_correlation],
#                             'features_name': [features_name],
#                             'features_name_number': [features_name_number],
#                             'sample_number_gdsc_drug':[sample_number_gdsc_drug],
#                             'Pearson_Correlation_P_Value_Train': [p_value_pearsonr],
#                             'Spearman_Correlation_Train': [corr_spearmanr],
#                             'Spearman_Correlation_P_Value_Train': [p_value_spearmanr],
#                             'RMSE_Train': [rmse_val]
#                              })
#
#
#                             Drug_dict[drug] = result_table_drug
#
#                             # Save results to files
#                             os.mkdir(os.path.join(output_dir_gdsc, histology, drug, "SVR - Regression"))
#                             result_table_drug.to_csv(os.path.join(output_dir_gdsc, histology, drug, "SVR - Regression", drug + "- Result_SVR_Reg.tsv"),
#                                      sep='\t', index=False, quoting=False)
#                             IC50_predict[drug] = pd.DataFrame({'Actual_IC50_Data': y_gdsc, 'Predicted_IC50_Data': y_gdsc_pred})
#                             IC50_predict[drug].to_csv(os.path.join(output_dir_gdsc, histology, drug, "SVR - Regression", drug + "- IC50_Result.tsv"),
#                                             sep='\t', index=False, quoting=False)
#
#
#
#
#     if Drug_dict:
#         Histology_dict[histology] = pd.concat(Drug_dict.values())  # Her bir histoloji için ilaç sonuçlarını birleştirin
#
# # Tüm histolojilerin sonuçlarını birleştirin ve dosyalara kaydedin
# if Histology_dict:
#     All_SVR_Result = pd.concat(Histology_dict.values())

# %%
Train_IC50_predict = dict()
Test_IC50_predict = dict()
Drug_dict = dict()  # Her histoloji için bir ilaç sözlüğü oluşturun
os.chdir(output_dir)
    
Drugs = [item1 for item1 in os.listdir() if os.path.isdir(item1)]
ind = 1
        
for drug in Drugs:
    os.chdir(os.path.join(output_dir, drug))
    expression_data = pd.read_csv(drug + " - Expression Data (IC50) - Normalized3.tsv", sep="\t")
    
    if len(expression_data.columns) > 2 and len(expression_data['Sample_Name'].unique()) > 20:
        print(f"\nDrug {ind}: Support Vector Regression is running for {drug}", flush=True)
        x1 = expression_data.drop(['Sample_Name', 'IC50'], axis=1)
        y1 = expression_data['IC50']
        
        if len(x1.columns)>= 5:
            x_train, x_test, y_train, y_test = train_test_split(x1, y1, test_size=0.30, random_state=42)
            
            loo = LeaveOneOut()
            svr_model = SVR(kernel='rbf')
            scores_loocv = cross_val_score(svr_model, x_train, y_train, cv=loo, scoring='neg_mean_squared_error')
            mean_score_loocv = scores_loocv.mean()

            # k-fold kullanılıyor.
            kfold = KFold(n_splits=2, random_state=1, shuffle = True)
            scores_kfold = cross_val_score(svr_model, x_train, y_train, cv=kfold, scoring='neg_mean_squared_error')
            mean_score_kfold = scores_kfold.mean()

            svr_model.fit(x_train, y_train)
            y_train_pred = svr_model.predict(x_train)
            y_test_pred = svr_model.predict(x_test)

            
                
            # Sonuçları toplama
            r_squared_train = r2_score(y_train, y_train_pred)
            pearson_correlation_train, p_value_train_pearsonr = pearsonr(y_train_pred, y_train)
            corr_train_spearmanr, p_value_train_spearmanr = spearmanr(y_train_pred, y_train)
            rmse_val_train = np.sqrt(mean_squared_error(y_train_pred, y_train))
                
            r_squared_test = r2_score(y_test, y_test_pred)
            pearson_correlation_test, p_value_test_pearsonr = pearsonr(y_test_pred, y_test)
            corr_test_spearmanr, p_value_test_spearmanr = spearmanr(y_test_pred, y_test)
            rmse_val_test = np.sqrt(mean_squared_error(y_test_pred, y_test))
                
            result_table_drug = pd.DataFrame({
                         
                        'Drug': drug,
                        'R_Square_Train': r_squared_train,
                        'R_Square_Test': r_squared_test,
                        'Pearson_Correlation_Train': pearson_correlation_train,
                        'Pearson_Correlation_Test': pearson_correlation_test,
                        'Pearson_Correlation_P_Value_Train': p_value_train_pearsonr,
                        'Pearson_Correlation_P_Value_Test': p_value_test_pearsonr,
                        'Spearman_Correlation_Train': corr_train_spearmanr,
                        'Spearman_Correlation_Test': corr_test_spearmanr,
                        'Spearman_Correlation_P_Value_Train': p_value_train_spearmanr,
                        'Spearman_Correlation_P_Value_Test': p_value_test_spearmanr,
                        'RMSE_Train': rmse_val_train,
                        'RMSE_Test': rmse_val_test
                }, index=[0])
                    
            Drug_dict[drug] = result_table_drug
            print(Drug_dict[drug])
                
            # Sonuçları dosyalara kaydetme
            os.mkdir(os.path.join(output_dir, drug, "Support Vector Regression"))
            result_table_drug.to_csv(os.path.join(output_dir, drug, "Support Vector Regression", drug + "- Result_SVR.tsv"), 
                                                 sep='\t', index=False, quoting=False)
            Train_IC50_predict[drug] = pd.DataFrame({'Actual_IC50_Train_Data': y_train, 'Predicted_IC50_Train_Data': y_train_pred})
            Train_IC50_predict[drug].to_csv(os.path.join(output_dir, drug, "Support Vector Regression", drug + "- IC50_Train_Result.tsv"), 
                                                        sep='\t', index=False, quoting=False)
            Test_IC50_predict[drug] = pd.DataFrame({'Actual_IC50_Test_Data': y_test, 'Predicted_IC50_Test_Data': y_test_pred})
            Test_IC50_predict[drug].to_csv(os.path.join(output_dir, drug, "Support Vector Regression", drug + "- IC50_Test_Result.tsv"), 
                                                       sep='\t', index=False, quoting=False)
                
            ind = ind + 1

if Drug_dict:
    All_Result_SVR_CCLE_without_separated_tissue = pd.concat(Drug_dict.values())
# Out:
# Drug 1: Support Vector Regression is running for 17-AAG
#      Drug  R_Square_Train  R_Square_Test  Pearson_Correlation_Train  \
# 0  17-AAG        0.066507        0.09868                   0.460494
#
#    Pearson_Correlation_Test  Pearson_Correlation_P_Value_Train  \
# 0                  0.465952                       1.120490e-17
#
#    Pearson_Correlation_P_Value_Test  Spearman_Correlation_Train  \
# 0                      1.398569e-08                    0.436218
#
#    Spearman_Correlation_Test  Spearman_Correlation_P_Value_Train  \
# 0                   0.217477                        7.849890e-16
#
#    Spearman_Correlation_P_Value_Test  RMSE_Train  RMSE_Test
# 0                           0.011597     0.50367   0.366131
#
# Drug 2: Support Vector Regression is running for AEW541
#      Drug  R_Square_Train  R_Square_Test  Pearson_Correlation_Train  \
# 0  AEW541        0.330906       0.182486                   0.597978
#
#    Pearson_Correlation_Test  Pearson_Correlation_P_Value_Train  \
# 0                  0.477357                       5.849013e-18
#
#    Pearson_Correlation_P_Value_Test  Spearman_Correlation_Train  \
# 0                          0.000017                    0.588684
#
#    Spearman_Correlation_Test  Spearman_Correlation_P_Value_Train  \
# 0                   0.489552                        2.502130e-17
#
#    Spearman_Correlation_P_Value_Test  RMSE_Train  RMSE_Test
# 0                            0.00001    1.864813   1.982538
#
# Drug 3: Support Vector Regression is running for AZD0530
#       Drug  R_Square_Train  R_Square_Test  Pearson_Correlation_Train  \
# 0  AZD0530        0.246921      -0.017698                   0.534117
#
#    Pearson_Correlation_Test  Pearson_Correlation_P_Value_Train  \
# 0                  0.144314                       4.415372e-09
#
#    Pearson_Correlation_P_Value_Test  Spearman_Correlation_Train  \
# 0                          0.344245                    0.574383
#
#    Spearman_Correlation_Test  Spearman_Correlation_P_Value_Train  \
# 0                   0.150593                        1.488968e-10
#
#    Spearman_Correlation_P_Value_Test  RMSE_Train  RMSE_Test
# 0                           0.323434    1.862809   2.425498
#
# Drug 4: Support Vector Regression is running for AZD6244
#       Drug  R_Square_Train  R_Square_Test  Pearson_Correlation_Train  \
# 0  AZD6244        0.207545      -0.056297                   0.678711
#
#    Pearson_Correlation_Test  Pearson_Correlation_P_Value_Train  \
# 0                  0.168507                       3.686527e-13
#
#    Pearson_Correlation_P_Value_Test  Spearman_Correlation_Train  \
# 0                          0.305153                    0.800077
#
#    Spearman_Correlation_Test  Spearman_Correlation_P_Value_Train  \
# 0                   0.210526                        8.752624e-21
#
#    Spearman_Correlation_P_Value_Test  RMSE_Train  RMSE_Test
# 0                           0.198291    1.634281   1.075774
#
# Drug 5: Support Vector Regression is running for Erlotinib
#         Drug  R_Square_Train  R_Square_Test  Pearson_Correlation_Train  \
# 0  Erlotinib        0.583229       0.102888                   0.792938
#
#    Pearson_Correlation_Test  Pearson_Correlation_P_Value_Train  \
# 0                  0.356202                       2.609021e-14
#
#    Pearson_Correlation_P_Value_Test  Spearman_Correlation_Train  \
# 0                          0.068206                    0.822686
#
#    Spearman_Correlation_Test  Spearman_Correlation_P_Value_Train  \
# 0                   0.343712                        4.216908e-16
#
#    Spearman_Correlation_P_Value_Test  RMSE_Train  RMSE_Test
# 0                           0.079191    1.504374    2.17111
#
# Drug 6: Support Vector Regression is running for Irinotecan
#          Drug  R_Square_Train  R_Square_Test  Pearson_Correlation_Train  \
# 0  Irinotecan        0.198051       0.066082                   0.559028
#
#    Pearson_Correlation_Test  Pearson_Correlation_P_Value_Train  \
# 0                  0.387925                       4.394469e-18
#
#    Pearson_Correlation_P_Value_Test  Spearman_Correlation_Train  \
# 0                          0.000188                    0.763326
#
#    Spearman_Correlation_Test  Spearman_Correlation_P_Value_Train  \
# 0                   0.647793                        5.298453e-40
#
#    Spearman_Correlation_P_Value_Test  RMSE_Train  RMSE_Test
# 0                       9.005842e-12    0.850371   1.224333
#
# Drug 7: Support Vector Regression is running for L-685458
#        Drug  R_Square_Train  R_Square_Test  Pearson_Correlation_Train  \
# 0  L-685458        0.257446        0.05726                   0.599109
#
#    Pearson_Correlation_Test  Pearson_Correlation_P_Value_Train  \
# 0                  0.466051                       4.255562e-07
#
#    Pearson_Correlation_P_Value_Test  Spearman_Correlation_Train  \
# 0                          0.016409                     0.66035
#
#    Spearman_Correlation_Test  Spearman_Correlation_P_Value_Train  \
# 0                   0.524786                        9.448558e-09
#
#    Spearman_Correlation_P_Value_Test  RMSE_Train  RMSE_Test
# 0                           0.005914    2.294887   2.325467
#
# Drug 8: Support Vector Regression is running for Lapatinib
#         Drug  R_Square_Train  R_Square_Test  Pearson_Correlation_Train  \
# 0  Lapatinib        0.411864       0.022417                   0.646956
#
#    Pearson_Correlation_Test  Pearson_Correlation_P_Value_Train  \
# 0                  0.296418                       3.544360e-13
#
#    Pearson_Correlation_P_Value_Test  Spearman_Correlation_Train  \
# 0                          0.050729                    0.637132
#
#    Spearman_Correlation_Test  Spearman_Correlation_P_Value_Train  \
# 0                   0.300916                        1.029547e-12
#
#    Spearman_Correlation_P_Value_Test  RMSE_Train  RMSE_Test
# 0                            0.04716    2.025262   2.338116
#
# Drug 9: Support Vector Regression is running for LBW242
#      Drug  R_Square_Train  R_Square_Test  Pearson_Correlation_Train  \
# 0  LBW242       -0.114223      -0.075909                   0.366368
#
#    Pearson_Correlation_Test  Pearson_Correlation_P_Value_Train  \
# 0                  0.422126                           0.071659
#
#    Pearson_Correlation_P_Value_Test  Spearman_Correlation_Train  \
# 0                          0.195917                        0.53
#
#    Spearman_Correlation_Test  Spearman_Correlation_P_Value_Train  \
# 0                   0.336364                            0.006429
#
#    Spearman_Correlation_P_Value_Test  RMSE_Train  RMSE_Test
# 0                           0.311824    2.411902   2.288331
#
# Drug 10: Support Vector Regression is running for Nilotinib
#         Drug  R_Square_Train  R_Square_Test  Pearson_Correlation_Train  \
# 0  Nilotinib        0.159154       0.204571                   0.471482
#
#    Pearson_Correlation_Test  Pearson_Correlation_P_Value_Train  \
# 0                  0.521802                           0.000006
#
#    Pearson_Correlation_P_Value_Test  Spearman_Correlation_Train  \
# 0                          0.000926                    0.456758
#
#    Spearman_Correlation_Test  Spearman_Correlation_P_Value_Train  \
# 0                   0.274775                            0.000013
#
#    Spearman_Correlation_P_Value_Test  RMSE_Train  RMSE_Test
# 0                           0.099789    2.251603   2.027255
#
# Drug 11: Support Vector Regression is running for Nutlin-3
#        Drug  R_Square_Train  R_Square_Test  Pearson_Correlation_Train  \
# 0  Nutlin-3         0.18854       0.039369                   0.644546
#
#    Pearson_Correlation_Test  Pearson_Correlation_P_Value_Train  \
# 0                  0.207691                            0.00161
#
#    Pearson_Correlation_P_Value_Test  Spearman_Correlation_Train  \
# 0                          0.591812                    0.662338
#
#    Spearman_Correlation_Test  Spearman_Correlation_P_Value_Train  \
# 0                   0.333333                            0.001071
#
#    Spearman_Correlation_P_Value_Test  RMSE_Train  RMSE_Test
# 0                           0.380713    1.813675   2.309864
#
# Drug 12: Support Vector Regression is running for Paclitaxel
#          Drug  R_Square_Train  R_Square_Test  Pearson_Correlation_Train  \
# 0  Paclitaxel       -0.051894      -1.282194                   0.343092
#
#    Pearson_Correlation_Test  Pearson_Correlation_P_Value_Train  \
# 0                  0.090772                       7.038268e-10
#
#    Pearson_Correlation_P_Value_Test  Spearman_Correlation_Train  \
# 0                          0.300619                   -0.038277
#
#    Spearman_Correlation_Test  Spearman_Correlation_P_Value_Train  \
# 0                   0.015809                            0.504717
#
#    Spearman_Correlation_P_Value_Test  RMSE_Train  RMSE_Test
# 0                           0.857217    0.163849    0.07965
#
# Drug 13: Support Vector Regression is running for PD-0325901
#          Drug  R_Square_Train  R_Square_Test  Pearson_Correlation_Train  \
# 0  PD-0325901        0.287518       0.150109                   0.710752
#
#    Pearson_Correlation_Test  Pearson_Correlation_P_Value_Train  \
# 0                   0.56292                       2.245969e-24
#
#    Pearson_Correlation_P_Value_Test  Spearman_Correlation_Train  \
# 0                          0.000001                    0.810996
#
#    Spearman_Correlation_Test  Spearman_Correlation_P_Value_Train  \
# 0                   0.579458                        2.820357e-36
#
#    Spearman_Correlation_P_Value_Test  RMSE_Train  RMSE_Test
# 0                       4.247772e-07    1.462838   1.724259
#
# Drug 14: Support Vector Regression is running for PD-0332991
#          Drug  R_Square_Train  R_Square_Test  Pearson_Correlation_Train  \
# 0  PD-0332991        0.153632       0.194491                   0.446598
#
#    Pearson_Correlation_Test  Pearson_Correlation_P_Value_Train  \
# 0                  0.449231                           0.000802
#
#    Pearson_Correlation_P_Value_Test  Spearman_Correlation_Train  \
# 0                          0.027651                    0.440816
#
#    Spearman_Correlation_Test  Spearman_Correlation_P_Value_Train  \
# 0                    0.55913                            0.000954
#
#    Spearman_Correlation_P_Value_Test  RMSE_Train  RMSE_Test
# 0                           0.004506    2.198342   2.025387
#
# Drug 15: Support Vector Regression is running for PF2341066
#         Drug  R_Square_Train  R_Square_Test  Pearson_Correlation_Train  \
# 0  PF2341066        0.228089       0.271145                    0.48204
#
#    Pearson_Correlation_Test  Pearson_Correlation_P_Value_Train  \
# 0                  0.583912                       4.852169e-09
#
#    Pearson_Correlation_P_Value_Test  Spearman_Correlation_Train  \
# 0                          0.000002                    0.531142
#
#    Spearman_Correlation_Test  Spearman_Correlation_P_Value_Train  \
# 0                    0.51413                        5.683251e-11
#
#    Spearman_Correlation_P_Value_Test  RMSE_Train  RMSE_Test
# 0                           0.000043    1.919473   1.815068
#
# Drug 16: Support Vector Regression is running for PHA-665752
#          Drug  R_Square_Train  R_Square_Test  Pearson_Correlation_Train  \
# 0  PHA-665752        0.116881      -0.106885                    0.59418
#
#    Pearson_Correlation_Test  Pearson_Correlation_P_Value_Train  \
# 0                 -0.150765                           0.000536
#
#    Pearson_Correlation_P_Value_Test  Spearman_Correlation_Train  \
# 0                           0.62297                    0.615128
#
#    Spearman_Correlation_Test  Spearman_Correlation_P_Value_Train  \
# 0                  -0.175824                            0.000298
#
#    Spearman_Correlation_P_Value_Test  RMSE_Train  RMSE_Test
# 0                            0.56558    2.322269   2.517232
#
# Drug 17: Support Vector Regression is running for PLX4720
#       Drug  R_Square_Train  R_Square_Test  Pearson_Correlation_Train  \
# 0  PLX4720         0.33569       0.398538                   0.588227
#
#    Pearson_Correlation_Test  Pearson_Correlation_P_Value_Train  \
# 0                  0.654402                           0.000027
#
#    Pearson_Correlation_P_Value_Test  Spearman_Correlation_Train  \
# 0                          0.002366                    0.694996
#
#    Spearman_Correlation_Test  Spearman_Correlation_P_Value_Train  \
# 0                   0.517544                        1.654556e-07
#
#    Spearman_Correlation_P_Value_Test  RMSE_Train  RMSE_Test
# 0                           0.023238    1.754406   1.868545
#
# Drug 18: Support Vector Regression is running for RAF265
#      Drug  R_Square_Train  R_Square_Test  Pearson_Correlation_Train  \
# 0  RAF265         0.09564       0.052038                   0.388441
#
#    Pearson_Correlation_Test  Pearson_Correlation_P_Value_Train  \
# 0                  0.404456                       2.073703e-09
#
#    Pearson_Correlation_P_Value_Test  Spearman_Correlation_Train  \
# 0                          0.000044                    0.390674
#
#    Spearman_Correlation_Test  Spearman_Correlation_P_Value_Train  \
# 0                   0.430426                        1.645923e-09
#
#    Spearman_Correlation_P_Value_Test  RMSE_Train  RMSE_Test
# 0                           0.000012    1.754376   2.211216
#
# Drug 19: Support Vector Regression is running for Sorafenib
#         Drug  R_Square_Train  R_Square_Test  Pearson_Correlation_Train  \
# 0  Sorafenib        0.217435        0.15014                   0.540824
#
#    Pearson_Correlation_Test  Pearson_Correlation_P_Value_Train  \
# 0                  0.548502                       6.385104e-08
#
#    Pearson_Correlation_P_Value_Test  Spearman_Correlation_Train  \
# 0                          0.000363                    0.568984
#
#    Spearman_Correlation_Test  Spearman_Correlation_P_Value_Train  \
# 0                   0.657293                        8.927700e-09
#
#    Spearman_Correlation_P_Value_Test  RMSE_Train  RMSE_Test
# 0                           0.000007    2.116715   1.795725
#
# Drug 20: Support Vector Regression is running for TAE684
#      Drug  R_Square_Train  R_Square_Test  Pearson_Correlation_Train  \
# 0  TAE684         0.20576       0.230876                   0.506082
#
#    Pearson_Correlation_Test  Pearson_Correlation_P_Value_Train  \
# 0                  0.513438                       1.713986e-16
#
#    Pearson_Correlation_P_Value_Test  Spearman_Correlation_Train  \
# 0                      4.692132e-08                    0.527223
#
#    Spearman_Correlation_Test  Spearman_Correlation_P_Value_Train  \
# 0                   0.548131                        5.346910e-18
#
#    Spearman_Correlation_P_Value_Test  RMSE_Train  RMSE_Test
# 0                       3.572247e-09    1.850935   1.733047
#
# Drug 21: Support Vector Regression is running for TKI258
#      Drug  R_Square_Train  R_Square_Test  Pearson_Correlation_Train  \
# 0  TKI258         0.18795        0.16798                   0.505149
#
#    Pearson_Correlation_Test  Pearson_Correlation_P_Value_Train  \
# 0                  0.455635                       2.140794e-12
#
#    Pearson_Correlation_P_Value_Test  Spearman_Correlation_Train  \
# 0                          0.000045                    0.503545
#
#    Spearman_Correlation_Test  Spearman_Correlation_P_Value_Train  \
# 0                   0.440533                        2.576785e-12
#
#    Spearman_Correlation_P_Value_Test  RMSE_Train  RMSE_Test
# 0                           0.000086    1.928775   1.948725
#
# Drug 22: Support Vector Regression is running for Topotecan
#         Drug  R_Square_Train  R_Square_Test  Pearson_Correlation_Train  \
# 0  Topotecan        0.086573       0.056588                   0.493727
#
#    Pearson_Correlation_Test  Pearson_Correlation_P_Value_Train  \
# 0                   0.47288                       2.485172e-20
#
#    Pearson_Correlation_P_Value_Test  Spearman_Correlation_Train  \
# 0                      1.031878e-08                    0.685791
#
#    Spearman_Correlation_Test  Spearman_Correlation_P_Value_Train  \
# 0                   0.664748                        3.948391e-44
#
#    Spearman_Correlation_P_Value_Test  RMSE_Train  RMSE_Test
# 0                       3.582515e-18    1.304446   1.372255
#
# Drug 23: Support Vector Regression is running for ZD-6474
#       Drug  R_Square_Train  R_Square_Test  Pearson_Correlation_Train  \
# 0  ZD-6474        0.338342       0.247011                   0.620089
#
#    Pearson_Correlation_Test  Pearson_Correlation_P_Value_Train  \
# 0                  0.542119                       2.039613e-14
#
#    Pearson_Correlation_P_Value_Test  Spearman_Correlation_Train  \
# 0                          0.000023                    0.659136
#
#    Spearman_Correlation_Test  Spearman_Correlation_P_Value_Train  \
# 0                   0.523537                        1.148656e-16
#
#    Spearman_Correlation_P_Value_Test  RMSE_Train  RMSE_Test
# 0                           0.000049    1.591741   1.607756

# %%
All_SVR_Result = All_Result_SVR_CCLE_without_separated_tissue.sort_values(by='R_Square_Test', ascending=False)
All_SVR_Result.to_excel('C:\\Users\\MONSTER\\Desktop\\TEZ SON\\CCLE\\OUTPUT3\\All_Result_SVR_CCLE_without_separated_tissue.xlsx', index=False)
