# %%
import os
import pandas as pd
import numpy as np
from warnings import filterwarnings
filterwarnings('ignore')

# %%
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
from sklearn import svm
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_validate

# %%
from sklearn.model_selection import LeaveOneOut, KFold, cross_val_score

# %%
output_dir_ccle = 'C:\\Users\\MONSTER\\Desktop\\BİYOİNFO 2\\PYTHON\\YAPAY ZEKA 2\\PROJE CCLE\\Project Output'
output_dir_gdsc = 'C:\\Users\\MONSTER\\Desktop\\BİYOİNFO 2\\PYTHON\\YAPAY ZEKA 2\\PROJE GDSC'

# %%
os.chdir(output_dir_ccle)

# %%
histologies = [item1 for item1 in os.listdir() if os.path.isdir(item1)]

# %%
All_drugs_for_one_histology = dict()

for histology in histologies:
    
    one_drug = dict()
    os.chdir(os.path.join(output_dir_ccle,histology))
    drugs_for_histology_ccle = [item1 for item1 in os.listdir() if os.path.isdir(item1)]
    os.chdir(os.path.join(output_dir_gdsc,histology))
    drugs_for_histology_gdsc = os.listdir()
    if len(drugs_for_histology_ccle) > 0 and len(drugs_for_histology_gdsc) > 0:
        commom_drug_ccle_gdsc = set(drugs_for_histology_ccle).intersection(drugs_for_histology_gdsc)
        if len(commom_drug_ccle_gdsc) > 0:
            for drug in commom_drug_ccle_gdsc:
                os.chdir(os.path.join(output_dir_ccle,histology,drug))
                if len(os.listdir()) > 1:
                    boruta_drug_data_ccle = pd.read_csv(os.path.join(output_dir_ccle,histology,drug,drug+" "+histology+" "+"- Expression Data(IC50).tsv"), sep = ",")
                    boruta_drug_data_ccle['log IC50 (uM)'].replace('S',1, inplace = True)
                    boruta_drug_data_ccle['log IC50 (uM)'].replace('R',0, inplace = True)
                    os.chdir(os.path.join(output_dir_gdsc,histology,drug))
                    if len(os.listdir()) > 0:
                        
                        boruta_drug_data_gdsc = pd.read_csv(os.path.join(output_dir_gdsc,histology,drug,drug+" "+histology+" "+"- GDSC Histology Project.tsv"), sep = "\t")
                        boruta_drug_data_gdsc[drug].replace('S',1, inplace = True)
                        boruta_drug_data_gdsc[drug].replace('R',0, inplace = True)
                        if len(boruta_drug_data_ccle.columns) > 3 and len(boruta_drug_data_gdsc.columns) > 4:
                            
                            x_ccle = boruta_drug_data_ccle.drop(['Unnamed: 0', 'Cell Line', 'log IC50 (uM)'], axis=1)
                            x_gdsc = boruta_drug_data_gdsc.drop(['Cell Line', 'GDSC\nTissue descriptor 1', 'GDSC\nTissue\ndescriptor 2', drug], axis=1)
                            commom_feature_ccle_gdsc = set(x_ccle.columns).intersection(x_gdsc.columns)
                            if len(commom_feature_ccle_gdsc) > 0:
                                print(histology)
                                print(drug)
                                
                                features_name = commom_feature_ccle_gdsc
                                sample_number_train_ccle_drug = len(boruta_drug_data_ccle['Cell Line'])
                                sample_number_test_gdsc_drug = len(boruta_drug_data_gdsc['Cell Line'])
                                x_ccle = x_ccle[list(commom_feature_ccle_gdsc)]
                                y_ccle = boruta_drug_data_ccle['log IC50 (uM)']
                                
                                x_gdsc = x_gdsc[list(commom_feature_ccle_gdsc)]
                                y_gdsc = boruta_drug_data_gdsc[drug]
                                
                                features_name_number= len((x_gdsc).columns)
                                
                                x_ccle = np.array(x_ccle)
                                y_ccle = np.array(y_ccle)
                                x_gdsc = np.array(x_gdsc)
                                y_gdsc = np.array(y_gdsc)
                                
                                
                                # MODEL OLUŞTURUYORUZ
                                
                                # LOOCV (Leave-One-Out Cross-Validation)
                                loo = LeaveOneOut()
                                svm_model = svm.SVC(kernel='rbf', C=1)
                                loo_scores = cross_val_score(svm_model, x_ccle, y_ccle, cv=loo)
                                
                                
                                # k-fold kullanılıyor.
                                kfold = KFold(n_splits=2, random_state=1, shuffle = True)
                            
                                scoring = ['accuracy', 'precision_macro', 'recall_macro', 'f1_macro']
                                cv_results = cross_validate(svm_model, x_ccle, y_ccle, cv=kfold, scoring=scoring)
                            
                                average_scores = {score: cv_results['test_'+score].mean() for score in scoring}
                                best_score_criteria = max(average_scores, key=average_scores.get)
                                best_model_index = np.argmax(cv_results['test_'+best_score_criteria])
                                best_model = svm_model
                                best_model.fit(x_ccle, y_ccle)
                                
                                # Tahmin yapılıyor.
                                y_gdsc_pred = best_model.predict(x_gdsc)

                            
                                avg_accuracy = cv_results['test_accuracy'].mean()
                                avg_precision = cv_results['test_precision_macro'].mean()
                                avg_recall = cv_results['test_recall_macro'].mean()
                                avg_f1 = cv_results['test_f1_macro'].mean()
                                                   
                                                            
                                if confusion_matrix(y_gdsc, y_gdsc_pred).shape == (2,2):
                                    tn, fp, fn, tp = confusion_matrix(y_gdsc, y_gdsc_pred).ravel()
                                    
                                    TN_value = tn
                                    FP_value = fp
                                    FN_value = fn
                                    TP_value = tp
                                    
                                    

                                    # Calculate the confusion matrix
                                    confusion = confusion_matrix(y_gdsc, y_gdsc_pred)

                                    class_labels = ['Resistant', 'Sensitive']
                                    
                                    # Create a DataFrame for the confusion matrix
                                    confusion_df = pd.DataFrame(confusion, index=class_labels, columns=class_labels)


                                    # Create a heatmap for visualisation
                                    plt.figure(figsize=(6, 4))
                                    sns.heatmap(confusion_df, annot=True, cmap='Blues', fmt='d', cbar=False)
                                    plt.xlabel('Predicted')
                                    plt.ylabel('Actual')
                                    plt.title(f'\nConfusion Matrix for {histology} {drug}')
                                    os.makedirs(os.path.join(output_dir_gdsc, histology, drug, "Result_svm_LOOCV"))
                                    os.chdir(os.path.join(output_dir_gdsc,histology,drug,"Result_svm_LOOCV"))
                                    plt.savefig('Confusion Matrix.png', bbox_inches='tight')
                                
                            
                                    fpr, tpr, thresholds = roc_curve(y_gdsc, y_gdsc_pred) 
                                    roc_auc = auc(fpr, tpr)
                                    # Plot the ROC curve
                                    plt.figure()  
                                    plt.plot(fpr, tpr, label='ROC curve (AUC = %0.2f)' % roc_auc)
                                    plt.plot([0, 1], [0, 1], 'k--', label='Random')
                                    plt.xlim([0.0, 1.0])
                                    plt.ylim([0.0, 1.05])
                                    plt.xlabel('False Positive Rate')
                                    plt.ylabel('True Positive Rate')
                                    plt.title(f'\nROC curve for {histology} {drug}')
                                    plt.legend()
                                    os.chdir(os.path.join(output_dir_gdsc,histology,drug,"Result_svm_LOOCV"))
                                    plt.savefig('ROC Curve.png')
                                    
                                    
                                    result_table_drug = pd.DataFrame({
                                   'Histology': [histology],
                                   'Drug': [drug],
                                   'Number of Sample-Train Data (CCLE)': [sample_number_train_ccle_drug],
                                   'Number of Sample-Test Data (GDSC) ': [sample_number_test_gdsc_drug],
                                   'Number of Feature': [features_name_number],
                                   'Name of Features': [features_name],
                                   'TPs (True Positives)': [TP_value],
                                   'TNs (True Negatives)': [TN_value],
                                   'FPs (False Positives)': [FP_value],
                                   'FNs (False Negatives)': [FN_value],
                                   'Precision': [avg_precision],
                                   'Recall': [avg_recall],
                                   'F1 Score': [avg_f1],
                                   'Accuracy': [avg_accuracy],
                                   'AUC': [roc_auc]   
                                   })
                                    one_drug[drug] = result_table_drug
                                    print(one_drug[drug])
                                
                                
    if one_drug:
        All_drugs_for_one_histology[histology] = pd.concat(one_drug)
                            
                            
    
if All_drugs_for_one_histology:
    All_histologies_drugs_result = pd.concat(All_drugs_for_one_histology)
# Out:
# aero_dig_tract
# AZD6244
#         Histology     Drug  Number of Sample-Train Data (CCLE)  \
# 0  aero_dig_tract  AZD6244                                  73
#
#    Number of Sample-Test Data (GDSC)   Number of Feature  Name of Features  \
# 0                                  67                  2  {METTL7A, NUAK1}
#
#    TPs (True Positives)  TNs (True Negatives)  FPs (False Positives)  \
# 0                     9                     0                     58
#
#    FNs (False Negatives)  Precision    Recall  F1 Score  Accuracy  AUC
# 0                      0   0.652778  0.535714  0.508523  0.807808  0.5
# breast
# 17-AAG
#   Histology    Drug  Number of Sample-Train Data (CCLE)  \
# 0    breast  17-AAG                                 279
#
#    Number of Sample-Test Data (GDSC)   Number of Feature Name of Features  \
# 0                                  44                  2     {LEO1, IDH1}
#
#    TPs (True Positives)  TNs (True Negatives)  FPs (False Positives)  \
# 0                     0                    41                      0
#
#    FNs (False Negatives)  Precision  Recall  F1 Score  Accuracy  AUC
# 0                      3   0.421133     0.5  0.457181  0.842266  0.5
# breast
# PD-0325901
#   Histology        Drug  Number of Sample-Train Data (CCLE)  \
# 0    breast  PD-0325901                                 136
#
#    Number of Sample-Test Data (GDSC)   Number of Feature Name of Features  \
# 0                                  43                  1         {POLR1D}
#
#    TPs (True Positives)  TNs (True Negatives)  FPs (False Positives)  \
# 0                     0                    38                      3
#
#    FNs (False Negatives)  Precision    Recall  F1 Score  Accuracy       AUC
# 0                      2   0.524621  0.518341   0.48039  0.794118  0.463415
# digestive_system
# 17-AAG
#           Histology    Drug  Number of Sample-Train Data (CCLE)  \
# 0  digestive_system  17-AAG                                 279
#
#    Number of Sample-Test Data (GDSC)   Number of Feature    Name of Features  \
# 0                                  43                  3  {PEX1, IDH1, BPTF}
#
#    TPs (True Positives)  TNs (True Negatives)  FPs (False Positives)  \
# 0                     0                    38                      0
#
#    FNs (False Negatives)  Precision  Recall  F1 Score  Accuracy  AUC
# 0                      5   0.421133     0.5  0.457181  0.842266  0.5
# digestive_system
# PD-0325901
#           Histology        Drug  Number of Sample-Train Data (CCLE)  \
# 0  digestive_system  PD-0325901                                 136
#
#    Number of Sample-Test Data (GDSC)   Number of Feature Name of Features  \
# 0                                  42                  2  {POLR1D, KCNQ1}
#
#    TPs (True Positives)  TNs (True Negatives)  FPs (False Positives)  \
# 0                     0                    38                      0
#
#    FNs (False Negatives)  Precision    Recall  F1 Score  Accuracy  AUC
# 0                      4   0.501786  0.532297  0.501786  0.786765  0.5
# digestive_system
# AZD6244
#           Histology     Drug  Number of Sample-Train Data (CCLE)  \
# 0  digestive_system  AZD6244                                  73
#
#    Number of Sample-Test Data (GDSC)   Number of Feature  \
# 0                                  40                  4
#
#                     Name of Features  TPs (True Positives)  \
# 0  {ARHGEF6, METTL7A, ZBTB8B, ASAP3}                     7
#
#    TNs (True Negatives)  FPs (False Positives)  FNs (False Negatives)  \
# 0                     1                     32                      0
#
#    Precision    Recall  F1 Score  Accuracy       AUC
# 0   0.856771  0.620536  0.639773  0.835586  0.515152
# kidney
# PD-0325901
#   Histology        Drug  Number of Sample-Train Data (CCLE)  \
# 0    kidney  PD-0325901                                 137
#
#    Number of Sample-Test Data (GDSC)   Number of Feature Name of Features  \
# 0                                  24                  2  {POLR1D, KCNE3}
#
#    TPs (True Positives)  TNs (True Negatives)  FPs (False Positives)  \
# 0                     0                    21                      0
#
#    FNs (False Negatives)  Precision    Recall  F1 Score  Accuracy  AUC
# 0                      3   0.574801  0.552885  0.536398  0.810102  0.5
# large_intestine
# 17-AAG
#          Histology    Drug  Number of Sample-Train Data (CCLE)  \
# 0  large_intestine  17-AAG                                 279
#
#    Number of Sample-Test Data (GDSC)   Number of Feature Name of Features  \
# 0                                  40                  1           {IDH1}
#
#    TPs (True Positives)  TNs (True Negatives)  FPs (False Positives)  \
# 0                     0                    39                      0
#
#    FNs (False Negatives)  Precision  Recall  F1 Score  Accuracy  AUC
# 0                      1   0.421133     0.5  0.457181  0.842266  0.5
# large_intestine
# PD-0325901
#          Histology        Drug  Number of Sample-Train Data (CCLE)  \
# 0  large_intestine  PD-0325901                                 136
#
#    Number of Sample-Test Data (GDSC)   Number of Feature  \
# 0                                  40                  4
#
#                  Name of Features  TPs (True Positives)  TNs (True Negatives)  \
# 0  {POLR1D, TENT2, KCNQ1, OGFRL1}                     0                    23
#
#    FPs (False Positives)  FNs (False Negatives)  Precision    Recall  \
# 0                      0                     17   0.501786  0.532297
#
#    F1 Score  Accuracy  AUC
# 0  0.501786  0.786765  0.5
# leukemia
# 17-AAG
#   Histology    Drug  Number of Sample-Train Data (CCLE)  \
# 0  leukemia  17-AAG                                  67
#
#    Number of Sample-Test Data (GDSC)   Number of Feature Name of Features  \
# 0                                  73                  1          {SIKE1}
#
#    TPs (True Positives)  TNs (True Negatives)  FPs (False Positives)  \
# 0                     0                    29                     44
#
#    FNs (False Negatives)  Precision    Recall  F1 Score  Accuracy  AUC
# 0                      0   0.446733  0.484848  0.463462  0.864973  NaN
# leukemia
# Crizotinib
#   Histology        Drug  Number of Sample-Train Data (CCLE)  \
# 0  leukemia  Crizotinib                                  49
#
#    Number of Sample-Test Data (GDSC)   Number of Feature Name of Features  \
# 0                                  68                  1          {PPIL6}
#
#    TPs (True Positives)  TNs (True Negatives)  FPs (False Positives)  \
# 0                     9                    22                     26
#
#    FNs (False Negatives)  Precision    Recall  F1 Score  Accuracy       AUC
# 0                     11   0.666688  0.619481  0.613289  0.654167  0.454167
# leukemia
# Paclitaxel
#   Histology        Drug  Number of Sample-Train Data (CCLE)  \
# 0  leukemia  Paclitaxel                                  66
#
#    Number of Sample-Test Data (GDSC)   Number of Feature Name of Features  \
# 0                                  68                  1           {GLMN}
#
#    TPs (True Positives)  TNs (True Negatives)  FPs (False Positives)  \
# 0                     0                     0                     68
#
#    FNs (False Negatives)  Precision    Recall  F1 Score  Accuracy  AUC
# 0                      0   0.595696  0.591437  0.573795  0.575758  NaN
# leukemia
# Lapatinib
#   Histology       Drug  Number of Sample-Train Data (CCLE)  \
# 0  leukemia  Lapatinib                                  28
#
#    Number of Sample-Test Data (GDSC)   Number of Feature Name of Features  \
# 0                                  68                  1          {PPIL6}
#
#    TPs (True Positives)  TNs (True Negatives)  FPs (False Positives)  \
# 0                     1                    13                     53
#
#    FNs (False Negatives)  Precision    Recall  F1 Score  Accuracy       AUC
# 0                      1   0.670833  0.660317  0.633347  0.642857  0.348485
# leukemia
# PD-0325901
#   Histology        Drug  Number of Sample-Train Data (CCLE)  \
# 0  leukemia  PD-0325901                                  21
#
#    Number of Sample-Test Data (GDSC)   Number of Feature Name of Features  \
# 0                                  73                  1          {ICAM1}
#
#    TPs (True Positives)  TNs (True Negatives)  FPs (False Positives)  \
# 0                    12                    19                     39
#
#    FNs (False Negatives)  Precision    Recall  F1 Score  Accuracy       AUC
# 0                      3   0.895833  0.895833  0.895833       0.9  0.563793
# leukemia
# PD-0332991
#   Histology        Drug  Number of Sample-Train Data (CCLE)  \
# 0  leukemia  PD-0332991                                  41
#
#    Number of Sample-Test Data (GDSC)   Number of Feature Name of Features  \
# 0                                  73                  1          {UTP11}
#
#    TPs (True Positives)  TNs (True Negatives)  FPs (False Positives)  \
# 0                     6                    29                     23
#
#    FNs (False Negatives)  Precision  Recall  F1 Score  Accuracy       AUC
# 0                     15        0.7   0.625  0.639986   0.90119  0.421703
# leukemia
# Nilotinib
#   Histology       Drug  Number of Sample-Train Data (CCLE)  \
# 0  leukemia  Nilotinib                                  31
#
#    Number of Sample-Test Data (GDSC)   Number of Feature Name of Features  \
# 0                                  72                  1       {SLC38A11}
#
#    TPs (True Positives)  TNs (True Negatives)  FPs (False Positives)  \
# 0                     5                    35                      5
#
#    FNs (False Negatives)  Precision    Recall  F1 Score  Accuracy       AUC
# 0                     27   0.667735  0.662969  0.631818  0.679167  0.515625
# lung
# Erlotinib
#   Histology       Drug  Number of Sample-Train Data (CCLE)  \
# 0      lung  Erlotinib                                  66
#
#    Number of Sample-Test Data (GDSC)   Number of Feature  \
# 0                                  56                  8
#
#                                     Name of Features  TPs (True Positives)  \
# 0  {IKBIP, CD6, S100A14, TBXA2R, AKAP5, CEACAM6, ...                     8
#
#    TNs (True Negatives)  FPs (False Positives)  FNs (False Negatives)  \
# 0                     3                     45                      0
#
#    Precision    Recall  F1 Score  Accuracy      AUC
# 0   0.469318  0.524306  0.483878  0.712121  0.53125
# lung
# 17-AAG
#   Histology    Drug  Number of Sample-Train Data (CCLE)  \
# 0      lung  17-AAG                                 287
#
#    Number of Sample-Test Data (GDSC)   Number of Feature Name of Features  \
# 0                                 153                  2  {EPB41L4B, NVL}
#
#    TPs (True Positives)  TNs (True Negatives)  FPs (False Positives)  \
# 0                     0                   145                      0
#
#    FNs (False Negatives)  Precision  Recall  F1 Score  Accuracy  AUC
# 0                      8    0.42338     0.5  0.458445  0.846761  0.5
# lung
# Crizotinib
#   Histology        Drug  Number of Sample-Train Data (CCLE)  \
# 0      lung  Crizotinib                                  94
#
#    Number of Sample-Test Data (GDSC)   Number of Feature Name of Features  \
# 0                                  65                  1         {CFAP58}
#
#    TPs (True Positives)  TNs (True Negatives)  FPs (False Positives)  \
# 0                     1                     8                     56
#
#    FNs (False Negatives)  Precision    Recall  F1 Score  Accuracy     AUC
# 0                      0   0.673737  0.548214  0.530071  0.755319  0.5625
# lung
# Lapatinib
#   Histology       Drug  Number of Sample-Train Data (CCLE)  \
# 0      lung  Lapatinib                                 100
#
#    Number of Sample-Test Data (GDSC)   Number of Feature Name of Features  \
# 0                                  64                  2    {PSD4, TMUB2}
#
#    TPs (True Positives)  TNs (True Negatives)  FPs (False Positives)  \
# 0                     4                    23                     34
#
#    FNs (False Negatives)  Precision    Recall  F1 Score  Accuracy       AUC
# 0                      3   0.438274  0.518849  0.462022      0.66  0.487469
# lung
# PD-0325901
#   Histology        Drug  Number of Sample-Train Data (CCLE)  \
# 0      lung  PD-0325901                                 139
#
#    Number of Sample-Test Data (GDSC)   Number of Feature  \
# 0                                 153                  7
#
#                                     Name of Features  TPs (True Positives)  \
# 0  {TRAF5, SIT1, S100A5, FHDC1, TRAPPC2, POLR1D, ...                     0
#
#    TNs (True Negatives)  FPs (False Positives)  FNs (False Negatives)  \
# 0                   139                      0                     14
#
#    Precision    Recall  F1 Score  Accuracy  AUC
# 0   0.847944  0.646828  0.661873  0.834161  0.5
# lung
# Sorafenib
#   Histology       Drug  Number of Sample-Train Data (CCLE)  \
# 0      lung  Sorafenib                                  66
#
#    Number of Sample-Test Data (GDSC)   Number of Feature Name of Features  \
# 0                                  65                  2  {TUSC3, AKR1C2}
#
#    TPs (True Positives)  TNs (True Negatives)  FPs (False Positives)  \
# 0                     0                    63                      0
#
#    FNs (False Negatives)  Precision  Recall  F1 Score  Accuracy  AUC
# 0                      2   0.454545     0.5  0.476058  0.909091  0.5
# lung
# AZD6244
#   Histology     Drug  Number of Sample-Train Data (CCLE)  \
# 0      lung  AZD6244                                  74
#
#    Number of Sample-Test Data (GDSC)   Number of Feature  \
# 0                                 147                  4
#
#            Name of Features  TPs (True Positives)  TNs (True Negatives)  \
# 0  {GJB6, SYF2, PEMT, AMPH}                    12                     3
#
#    FPs (False Positives)  FNs (False Negatives)  Precision  Recall  F1 Score  \
# 0                    132                      0   0.398649     0.5  0.443578
#
#    Accuracy       AUC
# 0  0.797297  0.511111
# lymphoma
# Paclitaxel
#   Histology        Drug  Number of Sample-Train Data (CCLE)  \
# 0  lymphoma  Paclitaxel                                  51
#
#    Number of Sample-Test Data (GDSC)   Number of Feature Name of Features  \
# 0                                  57                  1           {ALAD}
#
#    TPs (True Positives)  TNs (True Negatives)  FPs (False Positives)  \
# 0                     3                     0                     54
#
#    FNs (False Negatives)  Precision    Recall  F1 Score  Accuracy  AUC
# 0                      0   0.712454  0.641026  0.623869  0.647692  0.5
# lymphoma
# Crizotinib
#   Histology        Drug  Number of Sample-Train Data (CCLE)  \
# 0  lymphoma  Crizotinib                                  36
#
#    Number of Sample-Test Data (GDSC)   Number of Feature Name of Features  \
# 0                                  58                  1          {PPIL6}
#
#    TPs (True Positives)  TNs (True Negatives)  FPs (False Positives)  \
# 0                     1                    35                     10
#
#    FNs (False Negatives)  Precision    Recall  F1 Score  Accuracy      AUC
# 0                     12   0.444444  0.577922    0.4588  0.527778  0.42735
# lymphoma
# NVP-TAE684
#   Histology        Drug  Number of Sample-Train Data (CCLE)  \
# 0  lymphoma  NVP-TAE684                                  36
#
#    Number of Sample-Test Data (GDSC)   Number of Feature   Name of Features  \
# 0                                  58                  2  {GABPB2, IGF2BP1}
#
#    TPs (True Positives)  TNs (True Negatives)  FPs (False Positives)  \
# 0                     0                    51                      0
#
#    FNs (False Negatives)  Precision  Recall  F1 Score  Accuracy  AUC
# 0                      7   0.361111     0.5  0.419355  0.722222  0.5
# lymphoma
# PD-0332991
#   Histology        Drug  Number of Sample-Train Data (CCLE)  \
# 0  lymphoma  PD-0332991                                  33
#
#    Number of Sample-Test Data (GDSC)   Number of Feature Name of Features  \
# 0                                  63                  1         {RIPOR2}
#
#    TPs (True Positives)  TNs (True Negatives)  FPs (False Positives)  \
# 0                     0                    59                      0
#
#    FNs (False Negatives)  Precision    Recall  F1 Score  Accuracy  AUC
# 0                      4   0.432292  0.421875  0.420567  0.729779  0.5
# nervous_system
# Paclitaxel
#         Histology        Drug  Number of Sample-Train Data (CCLE)  \
# 0  nervous_system  Paclitaxel                                  25
#
#    Number of Sample-Test Data (GDSC)   Number of Feature  Name of Features  \
# 0                                  25                  2  {RPL11, LDLRAP1}
#
#    TPs (True Positives)  TNs (True Negatives)  FPs (False Positives)  \
# 0                     0                    23                      0
#
#    FNs (False Negatives)  Precision  Recall  F1 Score  Accuracy  AUC
# 0                      2   0.419872     0.5  0.456439  0.839744  0.5
# pancreas
# 17-AAG
#   Histology    Drug  Number of Sample-Train Data (CCLE)  \
# 0  pancreas  17-AAG                                 279
#
#    Number of Sample-Test Data (GDSC)   Number of Feature Name of Features  \
# 0                                  24                  2     {LEO1, IDH1}
#
#    TPs (True Positives)  TNs (True Negatives)  FPs (False Positives)  \
# 0                     0                    22                      0
#
#    FNs (False Negatives)  Precision  Recall  F1 Score  Accuracy  AUC
# 0                      2   0.421133     0.5  0.457181  0.842266  0.5
# pancreas
# PD-0325901
#   Histology        Drug  Number of Sample-Train Data (CCLE)  \
# 0  pancreas  PD-0325901                                 136
#
#    Number of Sample-Test Data (GDSC)   Number of Feature Name of Features  \
# 0                                  23                  1         {POLR1D}
#
#    TPs (True Positives)  TNs (True Negatives)  FPs (False Positives)  \
# 0                     1                     7                      5
#
#    FNs (False Negatives)  Precision    Recall  F1 Score  Accuracy       AUC
# 0                     10   0.524621  0.518341   0.48039  0.794118  0.337121
# skin
# 17-AAG
#   Histology    Drug  Number of Sample-Train Data (CCLE)  \
# 0      skin  17-AAG                                  32
#
#    Number of Sample-Test Data (GDSC)   Number of Feature Name of Features  \
# 0                                  45                  1           {MAOB}
#
#    TPs (True Positives)  TNs (True Negatives)  FPs (False Positives)  \
# 0                     0                    37                      0
#
#    FNs (False Negatives)  Precision  Recall  F1 Score  Accuracy  AUC
# 0                      8   0.421875     0.5  0.457471   0.84375  0.5
# skin
# PD-0325901
#   Histology        Drug  Number of Sample-Train Data (CCLE)  \
# 0      skin  PD-0325901                                  34
#
#    Number of Sample-Test Data (GDSC)   Number of Feature  \
# 0                                  43                  3
#
#         Name of Features  TPs (True Positives)  TNs (True Negatives)  \
# 0  {SHTN1, MN1, RNF144A}                     1                    13
#
#    FPs (False Positives)  FNs (False Negatives)  Precision    Recall  \
# 0                      0                     29   0.788324  0.764583
#
#    F1 Score  Accuracy       AUC
# 0  0.768611  0.794118  0.516667
# urogenital_system
# PD-0325901
#            Histology        Drug  Number of Sample-Train Data (CCLE)  \
# 0  urogenital_system  PD-0325901                                 137
#
#    Number of Sample-Test Data (GDSC)   Number of Feature Name of Features  \
# 0                                  91                  1         {POLR1D}
#
#    TPs (True Positives)  TNs (True Negatives)  FPs (False Positives)  \
# 0                     0                    68                      8
#
#    FNs (False Negatives)  Precision    Recall  F1 Score  Accuracy       AUC
# 0                     15   0.859356  0.636561  0.668956   0.84676  0.447368
# urogenital_system
# Nilotinib
#            Histology       Drug  Number of Sample-Train Data (CCLE)  \
# 0  urogenital_system  Nilotinib                                  62
#
#    Number of Sample-Test Data (GDSC)   Number of Feature Name of Features  \
# 0                                  71                  1         {MRPL41}
#
#    TPs (True Positives)  TNs (True Negatives)  FPs (False Positives)  \
# 0                     1                    47                     19
#
#    FNs (False Negatives)  Precision    Recall  F1 Score  Accuracy       AUC
# 0                      4   0.588972  0.588073  0.585284  0.612903  0.456061

# %%
All_histologies_drugs_result_new_svm = All_histologies_drugs_result.sort_values(by='AUC', ascending=False)

# %%
All_histologies_drugs_result_new_svm.to_excel(os.path.join(output_dir_gdsc, "All RESULT_SVM_Classification_LOOCV .xlsx"), index=False)
