# %%
import os
import pandas as pd
import numpy as np
from warnings import filterwarnings
filterwarnings('ignore')

# %%
from sklearn.model_selection import cross_val_predict
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_validate
from sklearn.model_selection import LeaveOneOut, KFold, cross_val_score

# %%
from sklearn.metrics import r2_score
from scipy.stats import pearsonr
from scipy.stats import spearmanr
from sklearn.metrics import mean_squared_error

# %%
output_dir_ccle = 'C:\\Users\\MONSTER\\Desktop\\TEZ SON\\CCLE\\OUTPUT - CCLE-GDSC'
output_dir_gdsc = 'C:\\Users\\MONSTER\\Desktop\\TEZ SON\\GDSC\\output'

# %%
os.chdir(output_dir_ccle)

# %%
Histologies = [item1 for item1 in os.listdir() if os.path.isdir(item1)]

# %%
Histologies
# Out:
# ['aero_dig_tract',
#  'breast',
#  'digestive_system',
#  'kidney',
#  'large_intestine',
#  'leukemia',
#  'lung',
#  'lymphoma',
#  'myeloma',
#  'nervous_system',
#  'pancreas',
#  'skin',
#  'thyroid',
#  'urogenital_system']

# %%
Histology_dict = dict()
Drug_dict = dict()
IC50_predict = dict()

for histology in Histologies:
    os.chdir(os.path.join(output_dir_ccle, histology))
    if len(os.listdir()) > 1:
        Drugs_ccle = [item1 for item1 in os.listdir() if os.path.isdir(item1)]
        
        os.chdir(os.path.join(output_dir_gdsc, histology))
        if len(os.listdir()) > 1:
            Drugs_gdsc = [item1 for item1 in os.listdir() if os.path.isdir(item1)]
            
            common_drug_ccle_gdsc = set(Drugs_ccle).intersection(Drugs_gdsc)
            if len(common_drug_ccle_gdsc) > 0:
                
                for drug in common_drug_ccle_gdsc:
                    
                    expression_data = pd.read_csv(os.path.join(output_dir_ccle,histology,drug,drug+" "+histology+" "+"- Expression Data(IC50).tsv"), sep = ",")
                    gdsc_train_data = pd.read_csv(os.path.join(output_dir_gdsc,histology,drug,drug+" "+histology+" "+"- GDSC Histology Project.tsv"), sep = "\t")
                    
                    if len(expression_data.columns) > 3 and len(expression_data['Cell Line']) > 20 and len(gdsc_train_data['Cell Line']) > 20:
                        
                        x_ccle = expression_data.drop(['Unnamed: 0', 'Cell Line', 'LN_IC50'], axis=1)
                        y_ccle = expression_data['LN_IC50']
                        
                        x_gdsc_1 = gdsc_train_data.drop(['Cell Line','GDSC\nTissue descriptor 1','LN_IC50','Drug'], axis=1)
                        y_gdsc = gdsc_train_data['LN_IC50']
                    
                        common_features_ccle_gdsc = set(x_ccle.columns).intersection(x_gdsc_1.columns)
                        if len(common_features_ccle_gdsc) > 0:
                            
                            features_name = common_features_ccle_gdsc
                            sample_number_gdsc_drug = len(gdsc_train_data['Cell Line'])
                        
                            x_ccle = x_ccle[list(features_name)]
                            #y_ccle = boruta_drug_data_ccle['log IC50 (uM)']
                                
                            x_gdsc = x_gdsc_1[list(features_name)]
                            #y_gdsc = boruta_drug_data_gdsc[drug]
                                
                            features_name_number= len((x_gdsc).columns)
                                
                            x_ccle = np.array(x_ccle)
                            y_ccle = np.array(y_ccle)
                            x_gdsc = np.array(x_gdsc)
                            y_gdsc = np.array(y_gdsc)
                        
                        
                            # MODEL OLUŞTURUYORUZ
                                
                            # LOOCV (Leave-One-Out Cross-Validation)
                            loo = LeaveOneOut()
                            rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
                            loo_scores = cross_val_score(rf_model, x_ccle, y_ccle, cv=loo)
                                
                                
                            # k-fold kullanılıyor.
                            kfold = KFold(n_splits=2, random_state=1, shuffle = True)
                            
                            cv_results = cross_validate(rf_model, x_ccle, y_ccle, cv=kfold, return_train_score=True)
                            
                            average_test_score = cv_results['test_score'].mean()
                            average_train_score = cv_results['train_score'].mean()
                            best_model_index = np.argmax(cv_results['test_score'])
                            best_model = rf_model
                            best_model.fit(x_ccle, y_ccle)
                                                    
                            
                                
                            # Tahmin yapılıyor.
                            y_gdsc_pred = best_model.predict(x_gdsc)                        

                            print(histology)
                            print(f"\nDrug : Random Forest is running for {drug}", flush=True)
            
                
                            r_squared = r2_score(y_gdsc, y_gdsc_pred)
                            pearson_correlation, p_value_pearsonr = pearsonr(y_gdsc_pred, y_gdsc)
                            corr_spearmanr, p_value_spearmanr = spearmanr(y_gdsc_pred, y_gdsc)
                            rmse_val = np.sqrt(mean_squared_error(y_gdsc_pred, y_gdsc))
                
                            features_name = list(features_name)
                            result_table_drug = pd.DataFrame({
                            'Tissue': [histology],
                            'Drug': [drug],
                            'R_Square': [r_squared],
                            'Pearson_Correlation_Train': [pearson_correlation],
                            'features_name': [features_name],
                            'features_name_number': [features_name_number],
                            'sample_number_gdsc_drug':[sample_number_gdsc_drug],    
                            'Pearson_Correlation_P_Value_Train': [p_value_pearsonr],
                            'Spearman_Correlation_Train': [corr_spearmanr],
                            'Spearman_Correlation_P_Value_Train': [p_value_spearmanr],
                            'RMSE_Train': [rmse_val]
                             })
            

                            Drug_dict[drug] = result_table_drug
                
                            # Save results to files
                            os.mkdir(os.path.join(output_dir_gdsc, histology, drug, "Random Forest - Regression"))
                            result_table_drug.to_csv(os.path.join(output_dir_gdsc, histology, drug, "Random Forest - Regression", drug + "- Result_RF_Reg.tsv"), 
                                     sep='\t', index=False, quoting=False)
                            IC50_predict[drug] = pd.DataFrame({'Actual_IC50_Data': y_gdsc, 'Predicted_IC50_Train_Data': y_gdsc_pred})
                            IC50_predict[drug].to_csv(os.path.join(output_dir_gdsc, histology, drug, "Random Forest - Regression", drug + "- IC50_Result.tsv"), 
                                            sep='\t', index=False, quoting=False)
                       
                    
                    
                    
    if Drug_dict:
        Histology_dict[histology] = pd.concat(Drug_dict.values())  # Her bir histoloji için ilaç sonuçlarını birleştirin

# Tüm histolojilerin sonuçlarını birleştirin ve dosyalara kaydedin
if Histology_dict:
    All_RF_Result = pd.concat(Histology_dict.values())
# Out:
# aero_dig_tract
#
# Drug : Random Forest is running for PD0325901
# aero_dig_tract
#
# Drug : Random Forest is running for AZD6244
# aero_dig_tract
#
# Drug : Random Forest is running for 17-AAG
# breast
#
# Drug : Random Forest is running for PD0325901
# breast
#
# Drug : Random Forest is running for AZD6244
# breast
#
# Drug : Random Forest is running for 17-AAG
# digestive_system
#
# Drug : Random Forest is running for Nilotinib
# digestive_system
#
# Drug : Random Forest is running for PD0325901
# digestive_system
#
# Drug : Random Forest is running for PLX-4720
# digestive_system
#
# Drug : Random Forest is running for AZD6244
# digestive_system
#
# Drug : Random Forest is running for 17-AAG
# kidney
#
# Drug : Random Forest is running for Nilotinib
# kidney
#
# Drug : Random Forest is running for PD0325901
# kidney
#
# Drug : Random Forest is running for AZD6244
# kidney
#
# Drug : Random Forest is running for 17-AAG
# large_intestine
#
# Drug : Random Forest is running for Nilotinib
# large_intestine
#
# Drug : Random Forest is running for PD0325901
# large_intestine
#
# Drug : Random Forest is running for AZD6244
# large_intestine
#
# Drug : Random Forest is running for 17-AAG
# leukemia
#
# Drug : Random Forest is running for Paclitaxel
# leukemia
#
# Drug : Random Forest is running for Nilotinib
# leukemia
#
# Drug : Random Forest is running for Sorafenib
# leukemia
#
# Drug : Random Forest is running for 17-AAG
# lung
#
# Drug : Random Forest is running for Paclitaxel
# lung
#
# Drug : Random Forest is running for Nilotinib
# lung
#
# Drug : Random Forest is running for PD0325901
# lung
#
# Drug : Random Forest is running for PLX-4720
# lung
#
# Drug : Random Forest is running for AZD-0530
# lung
#
# Drug : Random Forest is running for Erlotinib
# lung
#
# Drug : Random Forest is running for AZD6244
# lung
#
# Drug : Random Forest is running for NVP-TAE684
# lung
#
# Drug : Random Forest is running for Lapatinib
# lung
#
# Drug : Random Forest is running for Sorafenib
# lung
#
# Drug : Random Forest is running for Crizotinib
# lung
#
# Drug : Random Forest is running for 17-AAG
# lymphoma
#
# Drug : Random Forest is running for Paclitaxel
# lymphoma
#
# Drug : Random Forest is running for PD-0332991
# lymphoma
#
# Drug : Random Forest is running for Crizotinib
# nervous_system
#
# Drug : Random Forest is running for 17-AAG
# pancreas
#
# Drug : Random Forest is running for Nilotinib
# pancreas
#
# Drug : Random Forest is running for PD0325901
# pancreas
#
# Drug : Random Forest is running for PLX-4720
# pancreas
#
# Drug : Random Forest is running for AZD6244
# pancreas
#
# Drug : Random Forest is running for 17-AAG
# skin
#
# Drug : Random Forest is running for PD0325901
# skin
#
# Drug : Random Forest is running for AZD6244
# skin
#
# Drug : Random Forest is running for 17-AAG
# urogenital_system
#
# Drug : Random Forest is running for Nilotinib
# urogenital_system
#
# Drug : Random Forest is running for PD0325901
# urogenital_system
#
# Drug : Random Forest is running for PLX-4720
# urogenital_system
#
# Drug : Random Forest is running for AZD6244
# urogenital_system
#
# Drug : Random Forest is running for 17-AAG

# %%
All_RF_Result = All_RF_Result.sort_values(by='R_Square', ascending=False)
All_RF_Result.to_excel('C:\\Users\\MONSTER\\Desktop\\TEZ SON\\CCLE\\ML RESULT\\RF Regression_CCLE_GDSC.xlsx', index=False)

# %%
from sklearn.model_selection import GridSearchCV

# %%
Histology_dict = dict()
Drug_dict = dict()
IC50_predict = dict()

for histology in Histologies:
    os.chdir(os.path.join(output_dir_ccle, histology))
    if len(os.listdir()) > 1:
        Drugs_ccle = [item1 for item1 in os.listdir() if os.path.isdir(item1)]
        
        os.chdir(os.path.join(output_dir_gdsc, histology))
        if len(os.listdir()) > 1:
            Drugs_gdsc = [item1 for item1 in os.listdir() if os.path.isdir(item1)]
            
            common_drug_ccle_gdsc = set(Drugs_ccle).intersection(Drugs_gdsc)
            if len(common_drug_ccle_gdsc) > 0:
                
                for drug in common_drug_ccle_gdsc:
                    
                    os.chdir(os.path.join(output_dir_ccle,histology,drug))
                    if len(os.listdir()) > 1:
                        expression_data = pd.read_csv(os.path.join(output_dir_ccle,histology,drug,drug+" "+histology+" "+"- Expression Data(IC50).tsv"), sep = ",")
                        
                        os.chdir(os.path.join(output_dir_gdsc,histology,drug))
                        if len(os.listdir()) > 1:
                            gdsc_train_data = pd.read_csv(os.path.join(output_dir_gdsc,histology,drug,drug+" "+histology+" "+"- GDSC Histology Project.tsv"), sep = "\t")
                            
                            if len(expression_data.columns) > 3 and len(expression_data['Cell Line']) > 20 and len(gdsc_train_data['Cell Line']) > 20:
                                x_ccle = expression_data.drop(['Unnamed: 0', 'Cell Line', 'LN_IC50'], axis=1)
                                y_ccle = expression_data['LN_IC50']
                        
                                x_gdsc_1 = gdsc_train_data.drop(['Cell Line','GDSC\nTissue descriptor 1','LN_IC50','Drug'], axis=1)
                                y_gdsc = gdsc_train_data['LN_IC50']
                                
                                common_features_ccle_gdsc = set(x_ccle.columns).intersection(x_gdsc_1.columns)
                                if len(common_features_ccle_gdsc) > 0:
                                    
                                    features_name = common_features_ccle_gdsc
                                    sample_number_gdsc_drug = len(gdsc_train_data['Cell Line'])
                        
                                    x_ccle = x_ccle[list(features_name)]
                                    print(x_ccle)
                                
                                    x_gdsc = x_gdsc_1[list(features_name)]
                                    print(x_gdsc)
                                
                                    features_name_number= len((x_gdsc).columns)
                                
                                    x_ccle = np.array(x_ccle)
                                    y_ccle = np.array(y_ccle)
                                    x_gdsc = np.array(x_gdsc)
                                    y_gdsc = np.array(y_gdsc)
                        
                        
                                    # MODEL OLUŞTURUYORUZ
                            
                                    param_grid = {
                                    'n_estimators': [100, 200, 300],
                                    'max_depth': [None, 10, 20, 30],
                                    'min_samples_split': [2, 5, 10],
                                    'min_samples_leaf': [1, 2, 4],
                                    'max_features': ['auto', 'sqrt', 'log2'] }
        
                                    model = RandomForestRegressor(random_state=42)
                                    grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=5, n_jobs=-1, verbose=2)
                                    grid_search.fit(x_ccle, y_ccle)
        
                                    best_model = grid_search.best_estimator_
        
                                    y_gdsc_pred = best_model.predict(x_gdsc)
                        

                                    print(histology)
                                    print(f"\nDrug : Random Forest is running for {drug}", flush=True)
            
                            
                                    r_squared = r2_score(y_gdsc, y_gdsc_pred)
                                    print(r_squared)
                                    pearson_correlation, p_value_pearsonr = pearsonr(y_gdsc_pred, y_gdsc)
                                    corr_spearmanr, p_value_spearmanr = spearmanr(y_gdsc_pred, y_gdsc)
                                    rmse_val = np.sqrt(mean_squared_error(y_gdsc_pred, y_gdsc))
                            
                
                                    features_name = list(features_name)
                                    result_table_drug = pd.DataFrame({
                                    'Tissue': [histology],
                                    'Drug': [drug],
                                    'R_Square': [r_squared],
                                    'Pearson_Correlation_Train': [pearson_correlation],
                                    'features_name': [features_name],
                                    'features_name_number': [features_name_number],
                                    'sample_number_gdsc_drug':[sample_number_gdsc_drug],    
                                    'Pearson_Correlation_P_Value_Train': [p_value_pearsonr],
                                    'Spearman_Correlation_Train': [corr_spearmanr],
                                    'Spearman_Correlation_P_Value_Train': [p_value_spearmanr],
                                    'RMSE_Train': [rmse_val]
                                     })
                                    print(result_table_drug)
                        
            

                                    Drug_dict[drug] = result_table_drug
                
                            # Save results to files
                            os.mkdir(os.path.join(output_dir_gdsc, histology, drug, "Random Forest - Regression DENEME hyper "))
                            result_table_drug.to_csv(os.path.join(output_dir_gdsc, histology, drug, "Random Forest - Regression DENEME hyper", drug + "- Result_RF_Reg.tsv"), 
                                     sep='\t', index=False, quoting=False)
                            IC50_predict[drug] = pd.DataFrame({'Actual_IC50_Data': y_gdsc, 'Predicted_IC50_Data': y_gdsc_pred})
                            IC50_predict[drug].to_csv(os.path.join(output_dir_gdsc, histology, drug, "Random Forest - Regression DENEME hyper", drug + "- IC50_Result.tsv"), 
                                            sep='\t', index=False, quoting=False)
                       
                    
                    
                    
    if Drug_dict:
        Histology_dict[histology] = pd.concat(Drug_dict.values())  # Her bir histoloji için ilaç sonuçlarını birleştirin

 #Tüm histolojilerin sonuçlarını birleştirin ve dosyalara kaydedin
if Histology_dict:
    All_RF_Result = pd.concat(Histology_dict.values())
# Out:
#       BCLAF3
# 0   5.397742
# 1   6.057872
# 2   6.270824
# 3   5.163112
# 4   5.483860
# ..       ...
# 68  7.158782
# 69  6.867650
# 70  6.164544
# 71  5.677891
# 72  6.416633
#
# [73 rows x 1 columns]
#        BCLAF3
# 0    5.277532
# 1    5.277532
# 2    5.719696
# 3    5.719696
# 4    5.667912
# ..        ...
# 133  4.506816
# 134  4.487679
# 135  4.487679
# 136  6.119404
# 137  6.119404
#
# [138 rows x 1 columns]
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# aero_dig_tract
#
# Drug : Random Forest is running for AZD6244
# -2.2600678713739217
#            Tissue     Drug  R_Square  Pearson_Correlation_Train features_name  \
# 0  aero_dig_tract  AZD6244 -2.260068                  -0.040452      [BCLAF3]
#
#    features_name_number  sample_number_gdsc_drug  \
# 0                     1                      138
#
#    Pearson_Correlation_P_Value_Train  Spearman_Correlation_Train  \
# 0                           0.637591                    0.040148
#
#    Spearman_Correlation_P_Value_Train  RMSE_Train
# 0                            0.640122    2.474144
#           PPA1    GPR176      ANO9      LIFR     DZIP1     S1PR3      TRAF5  \
# 0    13.063837  7.866033  4.903812  4.162734  6.138745  6.298294   5.802459
# 1    11.641005  9.916367  3.983278  5.776309  6.919478  8.020698   7.274310
# 2    12.977355  9.170031  4.306189  7.154704  6.476754  7.539024   6.184136
# 3    13.437762  5.195887  4.272222  3.797005  9.057685  5.905235   9.135248
# 4    13.240696  5.767805  4.959426  5.271027  6.416380  8.823749   7.217360
# ..         ...       ...       ...       ...       ...       ...        ...
# 132  13.298970  7.553676  5.765247  5.758359  6.612907  6.320491   7.168684
# 133  13.056763  6.640970  5.363998  4.456198  7.143719  4.616759   7.289036
# 134  13.497337  8.326723  4.247620  4.747281  8.420282  4.830724   7.454490
# 135  13.475345  7.585936  4.767296  5.663632  6.483802  5.172657   7.608861
# 136  13.016405  4.985924  4.680995  5.002483  6.493716  6.536918  10.213139
#
#          MTIF3    S100A5     GLB1L2      CSRP2      DPYS    NBEAL2      DSEL
# 0    10.086833  3.928242   6.378038   8.943344  3.443441  5.428737  5.115644
# 1     8.872919  4.467723   4.996384   9.769418  3.641864  5.106530  6.914190
# 2     9.087648  4.037549   7.499897   8.346400  3.575026  4.841962  8.430745
# 3     9.930147  3.790335   7.437470   9.838572  3.650582  5.372546  4.865368
# 4     9.377596  4.123686   6.618696   9.296135  3.794905  5.442678  4.343068
# ..         ...       ...        ...        ...       ...       ...       ...
# 132   9.056929  3.771047   4.623796  10.835437  3.722890  5.183744  5.200239
# 133   8.797609  4.228788   6.142166   9.987074  3.598748  5.047667  4.146587
# 278   7.081992  4.786646  7.572343  6.754050  12.401074  6.830605  7.293325
# 279   7.013766  4.355848  4.374374  6.430324  11.999385  7.587405  9.531237
# 280   7.519229  4.138207  4.518213  9.120302  12.493298  7.766444  8.582176
#
#        ATP5IF1
# 0    10.136715
# 1     8.286880
# 2     8.642512
# 3     7.896585
# 4     8.690230
# ..         ...
# 276   8.869256
# 277   7.899667
# 278   7.845566
# 279   9.182730
# 280   7.493980
#
# [281 rows x 8 columns]
#         CADM1       MN1     MOXD1   RAP1GAP       NQO1      TUT7   ZFYVE19  \
# 0    3.707693  3.881035  3.606017  7.460756  10.768883  5.608432  7.433367
# 1    9.184638  6.044501  6.132065  4.184644  12.495699  6.321926  7.081266
# 2    8.228362  6.396826  3.759364  5.364524  11.764493  5.630813  7.529325
# 3    7.064362  3.991852  5.482325  4.039074   7.354860  6.741801  7.507384
# 4    5.211076  5.221736  4.084406  7.041662   9.524338  5.142586  6.022845
# ..        ...       ...       ...       ...        ...       ...       ...
# 65  10.172531  3.905040  3.568608  4.036793   9.707747  5.279943  7.009131
# 66   3.735016  4.994429  4.571310  4.094420  12.162756  5.755418  6.926052
# 67   7.543880  3.892915  7.219924  7.239528  11.492421  4.475260  6.932498
# 68   3.706701  6.400678  4.848558  5.477123  12.995864  5.802008  6.993870
# 69   4.242682  3.978141  3.753733  4.081411  11.565817  7.345993  7.325486
#
#       ATP5IF1
# 0   10.132817
# 1    8.391114
# 2    8.998159
# 3    8.907868
# 4    9.740515
# ..        ...
# 65   8.066100
# 66   7.993875
# 67   9.020182
# 68   9.501221
# 69   8.895024
#
# [70 rows x 8 columns]
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# aero_dig_tract
#
# Drug : Random Forest is running for 17-AAG
# -0.38818790046041585
#            Tissue    Drug  R_Square  Pearson_Correlation_Train  \
# 0  aero_dig_tract  17-AAG -0.388188                  -0.152373
#
#                                        features_name  features_name_number  \
# 0  [CADM1, MN1, MOXD1, RAP1GAP, NQO1, TUT7, ZFYVE...                     8
#
#    sample_number_gdsc_drug  Pearson_Correlation_P_Value_Train  \
# 0                       70                           0.207937
#
#    Spearman_Correlation_Train  Spearman_Correlation_P_Value_Train  RMSE_Train
# 0                   -0.087394                            0.471893    1.750909
#       BCLAF3
# 0   5.397742
# 1   6.057872
# 2   6.270824
# 3   5.163112
# 4   5.483860
# ..       ...
# 68  7.158782
# 69  6.867650
# 70  6.164544
# 71  5.677891
# 72  6.416633
#
# [73 rows x 1 columns]
#       BCLAF3
# 0   4.951954
# 1   4.797781
# 2   4.797781
# 3   4.384341
# 4   4.384341
# ..       ...
# 82  4.723029
# 83  4.723029
# 84  6.234461
# 85  5.113683
# 86  5.113683
#
# [87 rows x 1 columns]
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# breast
#
# Drug : Random Forest is running for AZD6244
# -7.010974315589062
#    Tissue     Drug  R_Square  Pearson_Correlation_Train features_name  \
# 0  breast  AZD6244 -7.010974                   0.039851      [BCLAF3]
#
#    features_name_number  sample_number_gdsc_drug  \
# 0                     1                       87
#
#    Pearson_Correlation_P_Value_Train  Spearman_Correlation_Train  \
# 0                           0.714009                    0.062675
#
#    Spearman_Correlation_P_Value_Train  RMSE_Train
# 0                            0
# 44  4.197332  5.626455
# 45  4.197332  5.626455
# 46  4.566570  5.056975
# 47  4.566570  5.056975
# 48  4.960879  4.590521
# 49  4.407964  4.525433
# 50  4.407964  4.525433
# 51  4.851697  4.587886
# 52  4.851697  4.587886
# 53  4.761163  5.499392
# 54  4.761163  5.499392
# 55  4.607223  4.756653
# 56  4.607223  4.756653
# 57  4.151124  4.578283
# 58  4.151124  4.578283
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# digestive_system
#
# Drug : Random Forest is running for AZD6244
# -1.210626490385882
#              Tissue     Drug  R_Square  Pearson_Correlation_Train  \
# 0  digestive_system  AZD6244 -1.210626                  -0.224916
#
#     features_name  features_name_number  sample_number_gdsc_drug  \
# 0  [IQCE, BCLAF3]                     2                       59
#
#    Pearson_Correlation_P_Value_Train  Spearman_Correlation_Train  \
# 0                           0.086774                   -0.237275
#
#    Spearman_Correlation_P_Value_Train  RMSE_Train
# 0                            0.070376    2.413806
#        RIPK3    ZBTB43     HCFC2
# 0   5.192765  7.056096  5.810859
# 1   4.913655  6.844151  5.984405
# 2   4.816033  7.684860  7.430015
# 3   4.969280  6.959080  5.783327
# 4   4.900242  6.705380  6.515928
# ..       ...       ...       ...
# 57  5.462321  6.891344  6.525342
# 58  4.978896  6.634344  6.698177
# 59  5.945446  7.592135  6.165299
# 60  4.788979  7.991597  7.145542
# 61  4.652934  6.887849  5.419427
#
# [62 rows x 3 columns]
#        RIPK3    ZBTB43     HCFC2
# 0   4.032185  6.400123  5.678476
# 1   4.643459  6.379787  5.842078
# 2   3.812187  6.847477  5.253698
# 3   3.925333  6.608641  5.193034
# 4   3.919797  6.410445  4.846516
# 5   3.841837  6.734759  5.414720
# 6   4.329650  6.575926  5.248155
# 7   5.799116  6.646408  5.657591
# 8   3.918000  6.391313  5.399773
# 9   4.026597  6.912543  4.812849
# 10  4.301138  6.820753  5.629396
# 11  3.662518  6.873378  5.511187
# 12  3.761240  6.334593  4.772200
# 13  3.801509  6.190649  4.749039
# 14  4.343018  6.636040  5.517495
# 15  3.628292  6.715111  5.421046
# 16  3.844108  6.828984  6.278749
# 17  3.843270  7.063740  5.003027
# 18  3.950905  6.964065  5.378236
# 19  3.588781  6.908840  6.467735
# 20  3.899335  6.509254  4.870929
# 21  4.114666  6.787149  4.861120
# 22  3.984674  7.934889  5.417762
# 23  4.067892  6.763468  4.856793
# 24  3.942133  7.531230  4.718603
# 25  6.194525  6.602337  5.919671
# 26  4.275577  6.610318  5.355061
# 27  3.983402  7.251365  4.969275
# 28  4.105512  8.197160  5.622884
# 29  3.531496  6.744099  5.640042
# 30  4.473277  6.633070  4.869199
# 31  3.957189  7.080753  4.904926
# 32  5.773413  6.520279  5.012700
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# digestive_system
#
# Drug : Random Forest is running for Nilotinib
# -7.7637191641625005
#              Tissue       Drug  R_Square  Pearson_Correlation_Train  \
# 0  digestive_system  Nilotinib -7.763719                  -0.099465
#
#             features_name  features_name_number  sample_number_gdsc_drug  \
# 0  [RIPK3, ZBTB43, HCFC2]                     3                       33
#
#    Pearson_Correlation_P_Value_Train  Spearman_Correlation_Train  \
# 0                           0.581825                   -0.108167
#
#    Spearman_Correlation_P_Value_Train  RMSE_Train
# 0                            0
# 27  4.145518  11.767908  8.462933  5.714109   9.667514  8.395078  3.983423
# 28  4.151758  12.048993  3.447115  5.567119   8.684590  8.476997  7.361960
# 29  5.061920  12.201066  3.686421  4.283754   8.015245  7.442473  8.055118
# 30  5.242749  12.804174  5.474648  4.058071   4.402322  9.151796  4.242544
#
#       NBEAL2
# 0   4.159510
# 1   5.110048
# 2   5.680975
# 3   4.475421
# 4   5.080108
# 5   4.197257
# 6   4.430360
# 7   4.619447
# 8   4.335788
# 9   5.324603
# 10  5.583124
# 11  4.469729
# 12  4.204510
# 13  4.754616
# 14  4.444215
# 15  4.399069
# 16  4.170043
# 17  4.304763
# 18  4.775731
# 19  4.131238
# 20  5.304482
# 21  4.961042
# 22  4.140077
# 23  6.739312
# 24  6.564759
# 25  5.312805
# 26  4.908971
# 27  3.856413
# 28  4.254132
# 29  4.399631
# 30  6.535051
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# digestive_system
#
# Drug : Random Forest is running for PD0325901
# -0.24063611005292018
#              Tissue       Drug  R_Square  Pearson_Correlation_Train  \
# 0  digestive_system  PD0325901 -0.240636                   0.142782
#
#                                        features_name  features_name_number  \
# 0  [SPNS2, PPA1, DZIP1, S1PR3, EXT1, MTIF3, GLB1L...                     8
#
#    sample_number_gdsc_drug  Pearson_Correlation_P_Value_Train  \
# 0                       31                           0.443531
#
#    Spearman_Correlation_Train  Spearman_Correlation_P_Value_Train  RMSE_Train
# 0                    0.129435                            0.487695    1.653282
#     SLC25A35      MDM1
# 0   5.456082  5.943038
# 1   6.176175  5.795447
# 2   5.998977  5.170915
# 3   6.422745  6.502993
# 4   7.781010  7.814769
# 5   7.272302  7.264124
# 6   6.019872  6.643982
# 7   6.019548  6.382118
# 8   5.580450  7.001877
# 9   5.993063  7.642795
# 10  6.266136  6.821721
# 11  7.159269  7.492084
# 12  6.039191  7.119505
# 13  6.727463  6.767765
# 14  6.483046  6.743986
# 15  6.582554  6.527124
# 16  6.129001  6.886945
# 17  7.079447  7.439118
# 18  6.083287  6.039362
# 19  6.630291  6.009034
# 20  6.176617  6.796166
# 21  6.466466  7.349596
# 22  6.555652  6.353159
#     SLC25A35      MDM1
# 0   4.784976  5.070527
# 1   4.784976  5.070527
# 2   5.267841  5.446657
# 3   5.267841  5.446657
# 4   4.430232  5.615061
# ..       ...       ...
# 57  5.293671  5.341169
# 58  4.638330  5.059169
# 59  4.638330  5.059169
# 60  4.506807  5.525143
# 61  4.506807  5.525143
#
# [62 rows x 2 columns]
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# digestive_system
#
# Drug : Random Forest is running for PLX-4720
# -10.235101554477602
#              Tissue      Drug   R_Square  Pearson_Correlation_Train  \
# 0  digestive_system  PLX-4720 -10.235102                   0.050094
#
#       features_name  features_name_number  sample_number_gdsc_drug  \
# 0  [SLC25A35, MDM1]                     2                       62
#
#    Pearson_Correlation_P_Value_Train  Spearman_Correlation_Train  \
# 0                            0.69901                   -0.097412
#
#    Spearman_Correlation_P_Value_Train  RMSE_Train
# 0                            0.451328    3.086625
#           NQO1   ZFYVE19
# 0     8.980115  8.910277
# 1    10.659003  8.528091
# 2     9.043453  7.349333
# 3    12.220304  7.224360
# 4    10.885993  7.463124
# ..         ...       ...
# 274  12.159712  9.392620
# 275  10.624908  7.365871
# 276  12.401074  7.293325
# 277  11.999385  9.531237
# 278  12.493298  8.582176
#
# [279 rows x 2 columns]
#          NQO1   ZFYVE19
# 0    5.427292  6.942616
# 1    9.367613  7.104171
# 2    9.834896  7.067992
# 3    6.901214  6.036957
# 3    8.464558   3.690563   9.717263  5.743546  6.550898  3.343976  8.432685
# 4    7.367693   3.875465   9.912115  6.617972  3.283811  3.184292  8.108381
# ..        ...        ...        ...       ...       ...       ...       ...
# 133  8.452541   3.848068   9.342628  7.230046  3.541759  3.460862  7.816347
# 134  8.101531  11.181269  10.356189  8.022947  3.580888  3.765046  8.796136
# 135  8.292234  11.479685  10.367528  6.715679  3.360537  3.251843  9.190299
# 136  8.838176  11.611718  10.141773  5.826800  5.361688  3.337897  8.806136
# 137  8.847817   9.644289   9.819632  6.955165  3.540379  3.745574  8.930588
#
#        NBEAL2     TARBP1
# 0    4.500239   8.455898
# 1    4.663199   8.884945
# 2    5.021997  10.055870
# 3    4.843500   8.756460
# 4    4.839644   9.126762
# ..        ...        ...
# 133  5.461135   8.111721
# 134  4.679577   8.436434
# 135  4.661838   8.997616
# 136  5.469385   8.329527
# 137  4.469862   7.330528
#
# [138 rows x 16 columns]
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# lung
#
# Drug : Random Forest is running for PD0325901
# -0.38773033420456193
#   Tissue       Drug  R_Square  Pearson_Correlation_Train  \
# 0   lung  PD0325901  -0.38773                  -0.128131
#
#                                        features_name  features_name_number  \
# 0  [MDFIC, PPA1, LIFR, RFK, DZIP1, F5, S1PR3, MTI...                    16
#
#    sample_number_gdsc_drug  Pearson_Correlation_P_Value_Train  \
# 0                      138                           0.134213
#
#    Spearman_Correlation_Train  Spearman_Correlation_P_Value_Train  RMSE_Train
# 0                    -0.12648                            0.139345    2.127213
#        CKAP2
# 0   6.391518
# 1   6.686879
# 2   7.377051
# 3   7.520988
# 4   8.946921
# 5   8.423164
# 6   6.553201
# 7   7.597278
# 8   6.835013
# 9   6.632599
# 10  7.413623
# 11  7.701268
# 12  8.582388
# 13  7.979752
# 14  7.600858
# 15  6.946165
# 16  6.796480
# 17  7.617649
# 18  7.991132
# 19  7.254024
# 20  6.369730
# 21  7.863887
# 22  7.989407
# 23  7.225715
#         CKAP2
# 0    7.293938
# 1    7.293938
# 2    5.831677
# 3    5.831677
# 4    7.426569
# ..        ...
# 268  7.181208
# 269  6.431470
# 270  6.431470
# 271  6.550425
# 272  6.550425
#
# [273 rows x 1 columns]
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# lung
#
# Drug : Random Forest is running for PLX-4720
# -8.159610283957377
#   Tissue      Drug  R_Square  Pearson_Correlation_Train features_name  \
# 0   lung  PLX-4720  -8.15961                   0.116353       [CKAP2]
#
#    features_name_number  sample_number_gdsc_drug  \
# 0                     1                      273
#
#    Pearson_Correlation_P_Value_Train  Spearman_Correlation_Train  \
# 0                           0.054835                   -0.000717
#
#    Spearman_Correlation_P_Value_Train  RMSE_Train
# 0                            0.990596    2.946553
#         ERBB2       GRB7       P3H1     ZBED4       FES   RAPGEF5      VAMP3  \
# 0    4.776857   7.051471   5.900716  7.537342  3.998420  7.051592  10.118159
# 1    5.594016   7.696131   7.783012  7.610711  4.295826  7.366431  11.428072
# 2    4.640193   6.344099   7.993085  7.083499  4.100984  8.061610  11.141334
# 3    4.728198   5.520133  10.482048  6.975462  3.899656  5.091089  12.326376
# 4    5.218538   5.685018   8.775206  8.053273  4.650884  4.594206  10.989516
# ..        ...        ...        ...       ...       ...       ...        ...
# 95   4.923872   6.371353   6.577290  6.999826  4.741956  7.835283  11.310866
# 96   6.240122   6.671821   6.648261  7.266958  4.235248  8.525056  11.221884
# 97   4.554882   5.797784  10.037570  6.897899  4.399291  7.484676  12.015713
# 98   4.510614   7.228966   7.924494  6.183771  3.902214  5.818736  11.430349
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# lung
#
# Drug : Random Forest is running for Lapatinib
# -2.8550480367972777
#   Tissue       Drug  R_Square  Pearson_Correlation_Train  \
# 0   lung  Lapatinib -2.855048                   0.003364
#
#                                        features_name  features_name_number  \
# 0  [ERBB2, GRB7, P3H1, ZBED4, FES, RAPGEF5, VAMP3...                     9
#
#    sample_number_gdsc_drug  Pearson_Correlation_P_Value_Train  \
# 0                       57                           0.980188
#
#    Spearman_Correlation_Train  Spearman_Correlation_P_Value_Train  RMSE_Train
# 0                    0.089448                            0.508175    2.352783
#           NQO1      ALCAM   ZFYVE19
# 0     8.980115   9.960699  8.910277
# 1    10.659003   9.752571  8.528091
# 2     9.043453   8.995110  7.349333
# 3    12.220304  10.072471  7.224360
# 4    10.885993   9.730142  7.463124
# ..         ...        ...       ...
# 282  12.159712   9.139984  9.392620
# 283  10.624908   9.895339  7.365871
# 284  12.401074  10.680587  7.293325
# 285  11.999385   9.740225  9.531237
# 286  12.493298   9.477634  8.582176
#
# [287 rows x 3 columns]
#           NQO1      ALCAM   ZFYVE19
# 0    10.447733   6.566468  6.768755
# 1     9.704761   5.114037  6.784294
# 2     6.547846   7.243424  7.097658
# 3     8.495833   6.667502  6.936943
# 4    10.049348   4.185412  7.285896
# ..         ...        ...       ...
# 132   9.397151   6.739085  7.073680
# 133   9.369461   8.225141  7.095448
# 134  12.554036   7.925892  7.508867
# 135  12.315702   6.882795  7.928434
# 136   8.297023  10.176097  7.818304
#
# [137 rows x 3 columns]
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# lung
#
# Drug : Random Forest is running for 17-AAG
# -0.37586731564417875
#   Tissue    Drug  R_Square  Pearson_Correlation_Train           features_name  \
# 0   lung  17-AAG -0.375867                   0.125332  [NQO1, ALCAM, ZFYVE19]
#
#    features_name_number  sample_number_gdsc_drug  \
# 0                     3                      137
#
#    Pearson_Correlation_P_Value_Train  Spearman_Correlation_Train  \
# 0                           0.144483                    0.126932
#
#    Spearman_Correlation_P_Value_Train  RMSE_Train
# 0                            0.139387    2.214025
#       GPR108
# 0   8.101857
# 1   7.165484
# 2   7.625307
# 3   8.665384
# 4   7.382189
# 5   7.801671
# 6   8.356237
# 7   8.191623
# 8   7.565143
# 9   7.868521
# 10  7.074622
# 11  7.266571
# 12  7.721381
# 13  7.898236
# 14  7.996978
# 15  9.792681
# 16  8.061356
# 17  7.581117
# 18  7.345968
# 19  7.904931
# 20  7.566999
# 21  7.590555
# 22  7.874225
# 23  7.547112
# 24  7.060678
# 25  7.093789
# 26  7.559214
# 27  7.907070
# 28  8.007041
# 29  8.078902
# 30  7.892907
# 31  7.447657
# 32  8.498104
#       GPR108
# 0   6.205286
# 1   6.103431
# 2   7.187970
# 3   6.526670
# 4   6.642905
# 5   7.023763
# 6   6.030447
# 7   7.400638
# 8   6.425603
# 9   7.787528
# 10  6.162935
# 11  5.805530
# 12  6.444946
# 13  6.753146
# 14  6.407565
# 15  7.242359
# 16  6.714112
# 17  6.785812
# 18  7.278437
# 19  5.724497
# 20  7.669246
# 21  6.683607
# 22  6.727980
# 23  6.862450
# 24  6.823970
# 25  7.068682
# 26  6.444657
# 27  6.277818
# 28  6.611180
# 29  6.992392
# 30  8.249888
# 31  6.195682
# 32  6.410069
# 33  6.049455
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# lymphoma
#
# Drug : Random Forest is running for PD-0332991
# -0.10633646133255459
#      Tissue        Drug  R_Square  Pearson_Correlation_Train features_name  \
# 0  lymphoma  PD-0332991 -0.106336                  -0.007949      [GPR108]
#
#    features_name_number  sample_number_gdsc_drug  \
# 0                     1                       34
#
#    Pearson_Correlation_P_Value_Train  Spearman_Correlation_Train  \
# 0                           0.964414                   -0.134146
#
#    Spearman_Correlation_P_Value_Train  RMSE_Train
# 0                            0.449426    1.363242
#       SLC9C2
# 0   3.406691
# 1   3.581992
# 2   3.799764
# 3   3.731359
# 4   3.338686
# 5   3.456435
# 6   3.648746
# 7   3.670180
# 8   3.659551
# 9   3.512329
# 10  3.345371
# 11  3.532710
# 12  3.558392
# 13  3.882621
# 14  4.134898
# 15  3.562557
# 16  3.303449
# 17  3.850568
# 18  3.555490
# 19  3.531408
# 20  3.419421
# 21  3.578770
# 22  3.481066
# 23  3.401576
# 24  3.474642
# 25  3.326060
# 26  3.641799
# 27  3.528885
# 28  3.474845
# 29  3.676568
# 30  3.681806
# 31  3.509218
# 32  3.550451
# 33  3.611569
# 34  3.703606
# 35  3.721712
# 36  3.540443
# 37  3.899523
# 38  3.525637
# 39  3.722837
# 40  3.570511
# 41  3.521918
# 42  3.390471
# 43  3.505984
# 44  3.563566
# 45  3.636231
# 46  3.619678
# 47  3.581495
# 48  3.504469
# 49  3.603221
# 50  3.555249
#       SLC9C2
# 0   3.338944
# 1   3.341970
# 2   3.324267
# 3   3.246923
# 4   3.248088
# 5   3.075671
# 6   3.189789
# 7   3.165986
# 8   3.477656
# 9   3.420659
# 10  3.329968
# 11  3.122340
# 12  3.201796
# 13  3.172711
# 14  3.247478
# 15  3.123654
# 16  3.178099
# 17  3.123476
# 18  3.337481
# 19  3.243760
# 20  3.232730
# 21  3.338010
# 22  3.335881
# 23  3.306902
# 24  3.113377
# 25  3.302849
# 26  3.303131
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits

# %%
Drug_dict[Nilotinib]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 Drug_dict[Nilotinib]
#
# NameError: name 'Drug_dict' is not defined

# %%
result_table_drug
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 result_table_drug
#
# NameError: name 'result_table_drug' is not defined

# %%
All_RF_Result = All_RF_Result.sort_values(by='R_Square', ascending=False)
All_RF_Result.to_excel('C:\\Users\\MONSTER\\Desktop\\TEZ SON\\CCLE\\ML RESULT\\RF Regression_CCLE_GDSC DENEME hyper.xlsx', index=False)

# %%
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# %%
Histology_dict = dict()
Drug_dict = dict()
IC50_predict = dict()

for histology in Histologies:
    os.chdir(os.path.join(output_dir_ccle, histology))
    if len(os.listdir()) > 1:
        Drugs_ccle = [item1 for item1 in os.listdir() if os.path.isdir(item1)]
        
        os.chdir(os.path.join(output_dir_gdsc, histology))
        if len(os.listdir()) > 1:
            Drugs_gdsc = [item1 for item1 in os.listdir() if os.path.isdir(item1)]
            
            common_drug_ccle_gdsc = set(Drugs_ccle).intersection(Drugs_gdsc)
            if len(common_drug_ccle_gdsc) > 0:
                
                for drug in common_drug_ccle_gdsc:
                    
                    expression_data = pd.read_csv(os.path.join(output_dir_ccle,histology,drug,drug+" "+histology+" "+"- Expression Data(IC50).tsv"), sep = ",")
                    gdsc_train_data = pd.read_csv(os.path.join(output_dir_gdsc,histology,drug,drug+" "+histology+" "+"- GDSC Histology Project.tsv"), sep = "\t")
                    
                    if len(expression_data.columns) > 3 and len(expression_data['Cell Line']) > 20 and len(gdsc_train_data['Cell Line']) > 20:
                        
                        x_ccle = expression_data.drop(['Unnamed: 0', 'Cell Line', 'LN_IC50'], axis=1)
                        y_ccle = expression_data['LN_IC50']
                        
                        x_gdsc_1 = gdsc_train_data.drop(['Cell Line','GDSC\nTissue descriptor 1','LN_IC50','Drug'], axis=1)
                        y_gdsc = gdsc_train_data['LN_IC50']
                    
                        common_features_ccle_gdsc = set(x_ccle.columns).intersection(x_gdsc_1.columns)
                        if len(common_features_ccle_gdsc) > 0:
                            
                            features_name = common_features_ccle_gdsc
                            sample_number_gdsc_drug = len(gdsc_train_data['Cell Line'])
                        
                            x_ccle = x_ccle[list(features_name)]
                            #y_ccle = boruta_drug_data_ccle['log IC50 (uM)']
                                
                            x_gdsc = x_gdsc_1[list(features_name)]
                            #y_gdsc = boruta_drug_data_gdsc[drug]
                                
                            features_name_number= len((x_gdsc).columns)
                                
                            x_ccle = np.array(x_ccle)
                            y_ccle = np.array(y_ccle)
                            x_gdsc = np.array(x_gdsc)
                            y_gdsc = np.array(y_gdsc)
                        
                        
                            # MODEL OLUŞTURUYORUZ
                            def perform_loocv(model, x_ccle, y_ccle):
                                loo = LeaveOneOut()
                                loo_scores = cross_val_score(model, x_ccle, y_ccle, cv=loo)
                                average_loo_score = loo_scores.mean()
                                print(f"LOOCV Average Score: {average_loo_score}")
                                return average_loo_score

                            def perform_kfold_cv(model, x_ccle, y_ccle, n_splits=2):
                                kfold = KFold(n_splits=n_splits, random_state=1, shuffle=True)
                                cv_results = cross_validate(model, x_ccle, y_ccle, cv=kfold, return_train_score=True)
                                average_test_score = cv_results['test_score'].mean()
                                average_train_score = cv_results['train_score'].mean()
                                best_model_index = np.argmax(cv_results['test_score'])
                                print(f"KFold CV Average Test Score: {average_test_score}")
                                print(f"KFold CV Average Train Score: {average_train_score}")
                                return cv_results, average_test_score, average_train_score, best_model_index

                            def train_and_predict(model, x_ccle, y_ccle, x_gdsc):
                                model.fit(x_ccle, y_ccle)
                                predictions = model.predict(x_gdsc)
                                return model, predictions

                            # Ana kodun çalıştırılması
                            try:
                            # LOOCV (Leave-One-Out Cross-Validation)
                                rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
                                loocv_score = perform_loocv(rf_model, x_ccle, y_ccle)
    
                            # K-Fold Cross-Validation
                                cv_results, avg_test_score, avg_train_score, best_model_index = perform_kfold_cv(rf_model, x_ccle, y_ccle, n_splits=2)
    
                            # En iyi modelin yeniden eğitilmesi
                                best_model, y_gdsc_pred = train_and_predict(rf_model, x_ccle, y_ccle, x_gdsc)
            
                            except Exception as e:
                                 
                                print(f"An error occurred: {e}")
                                
                                
                            # Tahmin yapılıyor.
                            y_gdsc_pred = best_model.predict(x_gdsc)                        

                            print(histology)
                            print(f"\nDrug : Random Forest is running for {drug}", flush=True)
            
                
                            r_squared = r2_score(y_gdsc, y_gdsc_pred)
                            pearson_correlation, p_value_pearsonr = pearsonr(y_gdsc_pred, y_gdsc)
                            corr_spearmanr, p_value_spearmanr = spearmanr(y_gdsc_pred, y_gdsc)
                            rmse_val = np.sqrt(mean_squared_error(y_gdsc_pred, y_gdsc))
                
                            features_name = list(features_name)
                            result_table_drug = pd.DataFrame({
                            'Tissue': [histology],
                            'Drug': [drug],
                            'R_Square': [r_squared],
                            'Pearson_Correlation_Train': [pearson_correlation],
                            'features_name': [features_name],
                            'features_name_number': [features_name_number],
                            'sample_number_gdsc_drug':[sample_number_gdsc_drug],    
                            'Pearson_Correlation_P_Value_Train': [p_value_pearsonr],
                            'Spearman_Correlation_Train': [corr_spearmanr],
                            'Spearman_Correlation_P_Value_Train': [p_value_spearmanr],
                            'RMSE_Train': [rmse_val]
                             })
            

                            Drug_dict[drug] = result_table_drug
                
                            # Save results to files
                            os.mkdir(os.path.join(output_dir_gdsc, histology, drug, "Random Forest - Regression2"))
                            result_table_drug.to_csv(os.path.join(output_dir_gdsc, histology, drug, "Random Forest - Regression2", drug + "- Result_RF_Reg.tsv"), 
                                     sep='\t', index=False, quoting=False)
                            IC50_predict[drug] = pd.DataFrame({'Actual_IC50_Data': y_gdsc, 'Predicted_IC50_Train_Data': y_gdsc_pred})
                            IC50_predict[drug].to_csv(os.path.join(output_dir_gdsc, histology, drug, "Random Forest - Regression2", drug + "- IC50_Result.tsv"), 
                                            sep='\t', index=False, quoting=False)
                       
                    
                    
                    
    if Drug_dict:
        Histology_dict[histology] = pd.concat(Drug_dict.values())  # Her bir histoloji için ilaç sonuçlarını birleştirin

# Tüm histolojilerin sonuçlarını birleştirin ve dosyalara kaydedin
if Histology_dict:
    All_RF_Result_2 = pd.concat(Histology_dict.values())
# Out:
# LOOCV Average Score: nan
# KFold CV Average Test Score: 0.22183643292489397
# KFold CV Average Train Score: 0.8647759587317352
# aero_dig_tract
#
# Drug : Random Forest is running for AZD6244
# LOOCV Average Score: nan
# KFold CV Average Test Score: 0.3361814083540588
# KFold CV Average Train Score: 0.9098221024025451
# aero_dig_tract
#
# Drug : Random Forest is running for 17-AAG
# LOOCV Average Score: nan
# KFold CV Average Test Score: 0.37224449770352314
# KFold CV Average Train Score: 0.9005149120161879
# aero_dig_tract
#
# Drug : Random Forest is running for PD0325901
# LOOCV Average Score: nan
# KFold CV Average Test Score: 0.22183643292489397
# KFold CV Average Train Score: 0.8647759587317352
# breast
#
# Drug : Random Forest is running for AZD6244
# LOOCV Average Score: nan
# KFold CV Average Test Score: 0.36388788526305693
# KFold CV Average Train Score: 0.9057498314549421
# breast
#
# Drug : Random Forest is running for 17-AAG
# LOOCV Average Score: nan
# KFold CV Average Test Score: 0.32653478617586873
# KFold CV Average Train Score: 0.9033027931630273
# breast
#
# Drug : Random Forest is running for PD0325901
# LOOCV Average Score: nan
# KFold CV Average Test Score: 0.6123968722084691
# KFold CV Average Train Score: 0.9264982654353853
# digestive_system
#
# Drug : Random Forest is running for Nilotinib
# LOOCV Average Score: nan
# KFold CV Average Test Score: 0.5572370799625532
# KFold CV Average Train Score: 0.9424480281284194
# digestive_system
#
# Drug : Random Forest is running for PLX-4720
# LOOCV Average Score: nan
# KFold CV Average Test Score: 0.2502284745494745
# KFold CV Average Train Score: 0.8887952633507225
# digestive_system
#
# Drug : Random Forest is running for AZD6244
# LOOCV Average Score: nan
# KFold CV Average Test Score: 0.22242441460688994
# KFold CV Average Train Score: 0.8887420785246062
# digestive_system
#
# Drug : Random Forest is running for 17-AAG
# LOOCV Average Score: nan
# KFold CV Average Test Score: 0.23505455334373354
# KFold CV Average Train Score: 0.896727929632918
# digestive_system
#
# Drug : Random Forest is running for PD0325901
# LOOCV Average Score: nan
# KFold CV Average Test Score: 0.6123968722084691
# KFold CV Average Train Score: 0.9264982654353853
# kidney
#
# Drug : Random Forest is running for Nilotinib
# LOOCV Average Score: nan
# KFold CV Average Test Score: 0.2502284745494745
# KFold CV Average Train Score: 0.8887952633507225
# kidney
#
# Drug : Random Forest is running for AZD6244
# LOOCV Average Score: nan
# KFold CV Average Test Score: 0.26206006957468203
# KFold CV Average Train Score: 0.8988903867579976
# kidney
#
# Drug : Random Forest is running for 17-AAG
# LOOCV Average Score: nan
# KFold CV Average Test Score: 0.39267597975946367
# KFold CV Average Train Score: 0.9070374456016667
# kidney
#
# Drug : Random Forest is running for PD0325901
# LOOCV Average Score: nan
# KFold CV Average Test Score: 0.6123968722084691
# KFold CV Average Train Score: 0.9264982654353853
# large_intestine
#
# Drug : Random Forest is running for Nilotinib
# LOOCV Average Score: nan
# KFold CV Average Test Score: 0.22183643292489397
# KFold CV Average Train Score: 0.8647759587317352
# large_intestine
#
# Drug : Random Forest is running for AZD6244
# LOOCV Average Score: nan
# KFold CV Average Test Score: 0.22242441460688994
# KFold CV Average Train Score: 0.8887420785246062
# large_intestine
#
# Drug : Random Forest is running for 17-AAG
# LOOCV Average Score: nan
# KFold CV Average Test Score: 0.2853619098149263
# KFold CV Average Train Score: 0.8896139440104536
# large_intestine
#
# Drug : Random Forest is running for PD0325901
# LOOCV Average Score: nan
# KFold CV Average Test Score: 0.646352939368443
# KFold CV Average Train Score: 0.9686680073477214
# leukemia
#
# Drug : Random Forest is running for Nilotinib
# LOOCV Average Score: nan
# KFold CV Average Test Score: -0.12315201647738983
# KFold CV Average Train Score: 0.8617122737123206
# leukemia
#
# Drug : Random Forest is running for Paclitaxel
# LOOCV Average Score: nan
# KFold CV Average Test Score: -0.7086383808762796
# KFold CV Average Train Score: 0.8888136262051247
# leukemia
#
# Drug : Random Forest is running for 17-AAG
# LOOCV Average Score: nan
# KFold CV Average Test Score: -0.27971984340719536
# KFold CV Average Train Score: 0.8037864780560586
# leukemia
#
# Drug : Random Forest is running for Sorafenib
# LOOCV Average Score: nan
# KFold CV Average Test Score: 0.7156828081577531
# KFold CV Average Train Score: 0.9209824717676804
# lung
#
# Drug : Random Forest is running for Nilotinib
# LOOCV Average Score: nan
# KFold CV Average Test Score: -0.049833148224927126
# KFold CV Average Train Score: 0.8468928498602724
# lung
#
# Drug : Random Forest is running for NVP-TAE684
# LOOCV Average Score: nan
# KFold CV Average Test Score: 0.42443071436892454
# KFold CV Average Train Score: 0.9084884793996336
# lung
#
# Drug : Random Forest is running for Lapatinib
# LOOCV Average Score: nan
# KFold CV Average Test Score: 0.3471214992152328
# KFold CV Average Train Score: 0.8819552922269034
# lung
#
# Drug : Random Forest is running for PLX-4720
# LOOCV Average Score: nan
# KFold CV Average Test Score: -0.22203359629274455
# KFold CV Average Train Score: 0.8088175091591678
# lung
#
# Drug : Random Forest is running for Erlotinib
# LOOCV Average Score: nan
# KFold CV Average Test Score: 0.21340680368486897
# KFold CV Average Train Score: 0.8606295443387186
# lung
#
# Drug : Random Forest is running for Crizotinib
# LOOCV Average Score: nan
# KFold CV Average Test Score: 0.16214008625527915
# KFold CV Average Train Score: 0.9090154306865684
# lung
#
# Drug : Random Forest is running for Paclitaxel
# LOOCV Average Score: nan
# KFold CV Average Test Score: 0.4209144237537368
# KFold CV Average Train Score: 0.8914686035923907
# lung
#
# Drug : Random Forest is running for AZD6244
# LOOCV Average Score: nan
# KFold CV Average Test Score: 0.26612609575829727
# KFold CV Average Train Score: 0.9061718914075714
# lung
#
# Drug : Random Forest is running for 17-AAG
# LOOCV Average Score: nan
# KFold CV Average Test Score: 0.4190114658740475
# KFold CV Average Train Score: 0.8831682457138231
# lung
#
# Drug : Random Forest is running for Sorafenib
# LOOCV Average Score: nan
# KFold CV Average Test Score: 0.413449025874959
# KFold CV Average Train Score: 0.909778572427492
# lung
#
# Drug : Random Forest is running for PD0325901
# LOOCV Average Score: nan
# KFold CV Average Test Score: -0.5552065103081613
# KFold CV Average Train Score: 0.8254437406486071
# lung
#
# Drug : Random Forest is running for AZD-0530
# LOOCV Average Score: nan
# KFold CV Average Test Score: 0.3567540688192101
# KFold CV Average Train Score: 0.8511275827778748
# lymphoma
#
# Drug : Random Forest is running for Crizotinib
# LOOCV Average Score: nan
# KFold CV Average Test Score: -0.5998708037104672
# KFold CV Average Train Score: 0.8448050538238345
# lymphoma
#
# Drug : Random Forest is running for Paclitaxel
# LOOCV Average Score: nan
# KFold CV Average Test Score: 0.3179948016323799
# KFold CV Average Train Score: 0.8814227109113465
# lymphoma
#
# Drug : Random Forest is running for PD-0332991
# LOOCV Average Score: nan
# KFold CV Average Test Score: -0.5314651911235071
# KFold CV Average Train Score: 0.8310086759012509
# nervous_system
#
# Drug : Random Forest is running for 17-AAG
# LOOCV Average Score: nan
# KFold CV Average Test Score: 0.5772295829270759
# KFold CV Average Train Score: 0.9223891870234973
# pancreas
#
# Drug : Random Forest is running for Nilotinib
# LOOCV Average Score: nan
# KFold CV Average Test Score: 0.04098543072431793
# KFold CV Average Train Score: 0.8470110851651426
# pancreas
#
# Drug : Random Forest is running for PLX-4720
# LOOCV Average Score: nan
# KFold CV Average Test Score: 0.22183643292489397
# KFold CV Average Train Score: 0.8647759587317352
# pancreas
#
# Drug : Random Forest is running for AZD6244
# LOOCV Average Score: nan
# KFold CV Average Test Score: 0.33597359459579496
# KFold CV Average Train Score: 0.8990836536595284
# pancreas
#
# Drug : Random Forest is running for 17-AAG
# LOOCV Average Score: nan
# KFold CV Average Test Score: 0.3465676905396432
# KFold CV Average Train Score: 0.9050014667172115
# pancreas
#
# Drug : Random Forest is running for PD0325901
# LOOCV Average Score: nan
# KFold CV Average Test Score: -0.24356908527364357
# KFold CV Average Train Score: 0.8662925393413183
# skin
#
# Drug : Random Forest is running for 17-AAG
# LOOCV Average Score: nan
# KFold CV Average Test Score: 0.3627038129678666
# KFold CV Average Train Score: 0.877623007199358
# skin
#
# Drug : Random Forest is running for AZD6244
# LOOCV Average Score: nan
# KFold CV Average Test Score: 0.5050960758606462
# KFold CV Average Train Score: 0.9521100164666524
# skin
#
# Drug : Random Forest is running for PD0325901
# LOOCV Average Score: nan
# KFold CV Average Test Score: 0.6010266231395787
# KFold CV Average Train Score: 0.8927714906797137
# urogenital_system
#
# Drug : Random Forest is running for Nilotinib
# LOOCV Average Score: nan
# KFold CV Average Test Score: 0.6183898981620746
# KFold CV Average Train Score: 0.9510078420500799
# urogenital_system
#
# Drug : Random Forest is running for PLX-4720
# LOOCV Average Score: nan
# KFold CV Average Test Score: 0.24180912153084494
# KFold CV Average Train Score: 0.897425383538271
# urogenital_system
#
# Drug : Random Forest is running for AZD6244
# LOOCV Average Score: nan
# KFold CV Average Test Score: 0.15355655110988747
# KFold CV Average Train Score: 0.8993580304966937
# urogenital_system
#
# Drug : Random Forest is running for 17-AAG
# LOOCV Average Score: nan
# KFold CV Average Test Score: 0.3413715888158616
# KFold CV Average Train Score: 0.9152607726928617
# urogenital_system
#
# Drug : Random Forest is running for PD0325901

# %%
All_RF_Result_2
# Out:
#             Tissue        Drug  R_Square  Pearson_Correlation_Train  \
# 0   aero_dig_tract     AZD6244 -2.659237                  -0.148357
# 0   aero_dig_tract      17-AAG -0.575868                  -0.176440
# 0   aero_dig_tract   PD0325901 -0.314562                  -0.143724
# 0           breast     AZD6244 -7.318106                   0.062813
# 0           breast      17-AAG -0.823174                  -0.272263
# ..             ...         ...       ...                        ...
# 0             lung   Lapatinib -3.443860                   0.006847
# 0             lung   Erlotinib -3.651930                   0.130137
# 0         lymphoma  Crizotinib -0.694361                   0.221129
# 0             lung    AZD-0530 -3.314896                   0.267668
# 0         lymphoma  PD-0332991 -0.248709                  -0.073480
#
#                                         features_name  features_name_number  \
# 0                                            [BCLAF3]                     1
# 0   [CADM1, MN1, ZFYVE19, NQO1, MOXD1, TUT7, RAP1G...                     8
# 0   [MTIF3, DPYS, S100A5, TRAF5, GPR176, NBEAL2, G...                    14
# 0                                            [BCLAF3]                     1
# 0   [ALCAM, CADM1, RAB27B, ZFYVE19, NQO1, TUT7, CE...                     7
# ..                                                ...                   ...
# 0   [VAMP3, FES, RAPGEF5, P3H1, MED24, MREG, ERBB2...                     9
# 0                                              [BCO2]                     1
# 0                                              [CPA1]                     1
# 0                                            [VCPIP1]                     1
# 0                                            [GPR108]                     1
#
#     sample_number_gdsc_drug  Pearson_Correlation_P_Value_Train  \
# 0                       138                           0.082463
# 0                        70                           0.143984
# 0                        70                           0.235225
# 0                        87                           0.563278
# 0                        45                           0.070396
# ..                      ...                                ...
# 0                        57                           0.959682
# 0                        57                           0.334616
# 0                        28                           0.258129
# 0                        55                           0.048189
# 0                        34                           0.679611
#
#     Spearman_Correlation_Train  Spearman_Correlation_P_Value_Train  RMSE_Train
# 0                    -0.098217                            0.251765    2.621241
# 0                    -0.100831                            0.406232    1.865517
# 0                    -0.179179                            0.137764    1.799991
# 0                     0.178855                            0.097416    3.658084
# 0                    -0.241765                            0.109596    2.252534
# ..                         ...                                 ...         ...
# 0                     0.043816                            0.746216    2.526080
# 0                    -0.015397                            0.909496    2.736471
# 0                     0.039378                            0.842304    1.263651
# 0                     0.133138                            0.332533    2.289754
# 0                    -0.066563                            0.708385    1.448306
#
# [131 rows x 11 columns]

# %%
All_RF_Result_2 = All_RF_Result_2.sort_values(by='R_Square', ascending=False)

# %%
All_RF_Result_2
# Out:
#                Tissue       Drug   R_Square  Pearson_Correlation_Train  \
# 0                skin    AZD6244  -0.074660                   0.080014
# 0                skin    AZD6244  -0.074660                   0.080014
# 0              kidney  PD0325901  -0.082097                   0.155112
# 0      nervous_system     17-AAG  -0.099847                  -0.183380
# 0            leukemia  Nilotinib  -0.104508                  -0.066327
# ..                ...        ...        ...                        ...
# 0                lung  Nilotinib -11.010172                  -0.051720
# 0            pancreas  Nilotinib -15.019855                  -0.543933
# 0            pancreas  Nilotinib -15.019855                  -0.543933
# 0            pancreas  Nilotinib -15.019855                  -0.543933
# 0   urogenital_system  Nilotinib -15.794618                   0.080447
#
#                                         features_name  features_name_number  \
# 0                                            [NKX2-3]                     1
# 0                                            [NKX2-3]                     1
# 0   [POLR1D, VLDLR, ZYG11A, PPA1, MIPOL1, EML1, DZ...                    20
# 0                                               [HJV]                     1
# 0   [BAIAP2, CSPP1, TGS1, ZNF451, ZNF557, ZNF471, ...                    12
# ..                                                ...                   ...
# 0                      [ZBTB43, MTMR11, HCFC2, RIPK3]                     4
# 0              [ZBTB43, RIPK3, LRRC66, TMEM54, HCFC2]                     5
# 0              [ZBTB43, RIPK3, LRRC66, TMEM54, HCFC2]                     5
# 0              [ZBTB43, RIPK3, LRRC66, TMEM54, HCFC2]                     5
# 0                                             [HCFC2]                     1
#
#     sample_number_gdsc_drug  Pearson_Correlation_P_Value_Train  \
# 0                        87                           0.461297
# 0                        87                           0.461297
# 0                        31                           0.404734
# 0                        53                           0.188720
# 0                        55                           0.630429
# ..                      ...                                ...
# 0                       139                           0.545398
# 0                        27                           0.003360
# 0                        27                           0.003360
# 0                        27                           0.003360
# 0                        79                           0.480948
#
#     Spearman_Correlation_Train  Spearman_Correlation_P_Value_Train  RMSE_Train
# 0                     0.127792                            0.238173    2.172315
# 0                     0.127792                            0.238173    2.172315
# 0                     0.092339                            0.621270    1.389095
# 0                    -0.297028                            0.030785    1.450146
# 0                     0.044449                            0.747277    2.926532
# ..                         ...                                 ...         ...
# 0                    -0.107439                            0.208070    2.476395
# 0                    -0.451770                            0.018000    2.397041
# 0                    -0.451770                            0.018000    2.397041
# 0                    -0.451770                            0.018000    2.397041
# 0                     0.098101                            0.389722    3.236144
#
# [131 rows x 11 columns]

# %%
def perform_loocv(model, X, y):
    loo = LeaveOneOut()
    loo_scores = cross_val_score(model, X, y, cv=loo)
    average_loo_score = loo_scores.mean()
    print(f"LOOCV Average Score: {average_loo_score}")
    return average_loo_score

def perform_kfold_cv(model, X, y, n_splits=2):
    kfold = KFold(n_splits=n_splits, random_state=1, shuffle=True)
    cv_results = cross_validate(model, X, y, cv=kfold, return_train_score=True)
    average_test_score = cv_results['test_score'].mean()
    average_train_score = cv_results['train_score'].mean()
    best_model_index = np.argmax(cv_results['test_score'])
    print(f"KFold CV Average Test Score: {average_test_score}")
    print(f"KFold CV Average Train Score: {average_train_score}")
    return cv_results, average_test_score, average_train_score, best_model_index

def train_and_predict(model, X_train, y_train, X_test):
    model.fit(X_train, y_train)
    predictions = model.predict(X_test)
    return model, predictions

# Ana kodun çalıştırılması
try:
    # LOOCV (Leave-One-Out Cross-Validation)
    rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
    loocv_score = perform_loocv(rf_model, x_ccle, y_ccle)
    
    # K-Fold Cross-Validation
    cv_results, avg_test_score, avg_train_score, best_model_index = perform_kfold_cv(rf_model, x_ccle, y_ccle, n_splits=2)
    
    # En iyi modelin yeniden eğitilmesi
    best_model, y_gdsc_pred = train_and_predict(rf_model, x_ccle, y_ccle, x_gdsc)
