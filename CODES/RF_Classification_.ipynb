# %%
import os
import pandas as pd
import numpy as np
from warnings import filterwarnings
filterwarnings('ignore')

# %%
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
import seaborn as sns

# %%
output_dir_ccle = 'C:\\Users\\MONSTER\\Desktop\\BİYOİNFO 2\\PYTHON\\YAPAY ZEKA 2\\PROJE CCLE\\Project Output'

# %%
output_dir_gdsc = 'C:\\Users\\MONSTER\\Desktop\\BİYOİNFO 2\\PYTHON\\YAPAY ZEKA 2\\PROJE GDSC'

# %%
os.chdir(output_dir_ccle)

# %%
histologies = [item1 for item1 in os.listdir() if os.path.isdir(item1)]

# %%
histologies
# Out:
# ['aero_dig_tract',
#  'breast',
#  'digestive_system',
#  'kidney',
#  'large_intestine',
#  'leukemia',
#  'lung',
#  'lymphoma',
#  'myeloma',
#  'nervous_system',
#  'pancreas',
#  'skin',
#  'thyroid',
#  'urogenital_system']

# %%
All_drugs_for_one_histology = dict()

for histology in histologies:
    
    one_drug = dict()
    os.chdir(os.path.join(output_dir_ccle,histology))
    drugs_for_histology_ccle = [item1 for item1 in os.listdir() if os.path.isdir(item1)]
    os.chdir(os.path.join(output_dir_gdsc,histology))
    drugs_for_histology_gdsc = os.listdir()
    if len(drugs_for_histology_ccle) > 0 and len(drugs_for_histology_gdsc) > 0:
        commom_drug_ccle_gdsc = set(drugs_for_histology_ccle).intersection(drugs_for_histology_gdsc)
        if len(commom_drug_ccle_gdsc) > 0:
            for drug in commom_drug_ccle_gdsc:
                os.chdir(os.path.join(output_dir_ccle,histology,drug))
                if len(os.listdir()) > 1:
                    boruta_drug_data_ccle = pd.read_csv(os.path.join(output_dir_ccle,histology,drug,drug+" "+histology+" "+"- Expression Data(IC50).tsv"), sep = ",")
                    boruta_drug_data_ccle['log IC50 (uM)'].replace('S',1, inplace = True)
                    boruta_drug_data_ccle['log IC50 (uM)'].replace('R',0, inplace = True)
                    os.chdir(os.path.join(output_dir_gdsc,histology,drug))
                    if len(os.listdir()) > 0:
                        
                        boruta_drug_data_gdsc = pd.read_csv(os.path.join(output_dir_gdsc,histology,drug,drug+" "+histology+" "+"- GDSC Histology Project.tsv"), sep = "\t")
                        boruta_drug_data_gdsc[drug].replace('S',1, inplace = True)
                        boruta_drug_data_gdsc[drug].replace('R',0, inplace = True)
                        if len(boruta_drug_data_ccle.columns) > 3 and len(boruta_drug_data_gdsc.columns) > 4:
                            
                            x_ccle = boruta_drug_data_ccle.drop(['Unnamed: 0', 'Cell Line', 'log IC50 (uM)'], axis=1)
                            x_gdsc = boruta_drug_data_gdsc.drop(['Cell Line', 'GDSC\nTissue descriptor 1', 'GDSC\nTissue\ndescriptor 2', drug], axis=1)
                            commom_feature_ccle_gdsc = set(x_ccle.columns).intersection(x_gdsc.columns)
                            if len(commom_feature_ccle_gdsc) > 0:
                                print(histology)
                                print(drug)
                                
                                features_name = commom_feature_ccle_gdsc
                                sample_number_train_ccle_drug = len(boruta_drug_data_ccle['Cell Line'])
                                sample_number_test_gdsc_drug = len(boruta_drug_data_gdsc['Cell Line'])
                                x_ccle = x_ccle[list(commom_feature_ccle_gdsc)]
                                y_ccle = boruta_drug_data_ccle['log IC50 (uM)']
                                
                                x_gdsc = x_gdsc[list(commom_feature_ccle_gdsc)]
                                y_gdsc = boruta_drug_data_gdsc[drug]
                                
                                features_name_number= len((x_gdsc).columns)
                                
                                x_ccle = np.array(x_ccle)
                                y_ccle = np.array(y_ccle)
                                x_gdsc = np.array(x_gdsc)
                                y_gdsc = np.array(y_gdsc)
                                
                                
                                
                                # MODEL OLUŞTURUYORUZ
                                rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
                                
                                rf_model.fit(x_ccle, y_ccle)
                                                           
                                y_gdsc_pred = rf_model.predict(x_gdsc)

                            
    
                                tn, fp, fn, tp = confusion_matrix(y_gdsc, y_gdsc_pred).ravel()
                                TN_value = tn
                                FP_value = fp
                                FN_value = fn
                                TP_value = tp
                                
                                class_labels = ['Resistant', 'Sensitive']

                                # Calculate the confusion matrix
                                confusion = confusion_matrix(y_gdsc, y_gdsc_pred)

                                # Create a DataFrame for the confusion matrix
                                confusion_df = pd.DataFrame(confusion, index=class_labels, columns=class_labels)
                                
                                accuracy = accuracy_score(y_gdsc, y_gdsc_pred)
                                precision = precision_score(y_gdsc, y_gdsc_pred, average='weighted')
                                recall = recall_score(y_gdsc, y_gdsc_pred, average='weighted')
                                f1 = f1_score(y_gdsc, y_gdsc_pred, average='weighted')


                                # Create a heatmap for visualisation
                                plt.figure(figsize=(6, 4))
                                sns.heatmap(confusion_df, annot=True, cmap='Blues', fmt='d', cbar=False)
                                plt.xlabel('Predicted')
                                plt.ylabel('Actual')
                                plt.title(f'\nConfusion Matrix for {histology} {drug}')
                                os.makedirs(os.path.join(output_dir_gdsc, histology, drug, "Result_rf"))
                                os.chdir(os.path.join(output_dir_gdsc,histology,drug,"Result_rf"))
                                plt.savefig('Confusion Matrix.png', bbox_inches='tight')
                                
                            
                                fpr, tpr, thresholds = roc_curve(y_gdsc, y_gdsc_pred) 
                                roc_auc = auc(fpr, tpr)
                                # Plot the ROC curve
                                plt.figure()  
                                plt.plot(fpr, tpr, label='ROC curve (AUC = %0.2f)' % roc_auc)
                                plt.plot([0, 1], [0, 1], 'k--', label='Random')
                                plt.xlim([0.0, 1.0])
                                plt.ylim([0.0, 1.05])
                                plt.xlabel('False Positive Rate')
                                plt.ylabel('True Positive Rate')
                                plt.title(f'\nROC curve for {histology} {drug}')
                                plt.legend()
                                os.chdir(os.path.join(output_dir_gdsc,histology,drug,"Result_rf"))
                                plt.savefig('ROC Curve.png')
                            
                            
                    
                                result_table_drug = pd.DataFrame({
                                'Histology': [histology],
                                'Drug': [drug],
                                'Number of Sample-Train Data (CCLE)': [sample_number_train_ccle_drug],
                                'Number of Sample-Test Data (GDSC) ': [sample_number_test_gdsc_drug],
                                'Number of Feature': [features_name_number],
                                'Name of Features': [features_name],
                                'TPs (True Positives)': [TP_value],
                                'TNs (True Negatives)': [TN_value],
                                'FPs (False Positives)': [FP_value],
                                'FNs (False Negatives)': [FN_value],
                                'Precision': [precision],
                                'Recall': [recall],
                                'F1 Score': [f1],
                                'Accuracy': [accuracy],
                                'AUC': [roc_auc]   
                                 })
                                one_drug[drug] = result_table_drug
                                print(one_drug[drug])
                                
                                
    if one_drug:
        All_drugs_for_one_histology[histology] = pd.concat(one_drug)
                            
                            
    
if All_drugs_for_one_histology:
    All_histologies_drugs_result = pd.concat(All_drugs_for_one_histology)
# Out:
# aero_dig_tract
# AZD6244
#         Histology     Drug  Number of Sample-Train Data (CCLE)  \
# 0  aero_dig_tract  AZD6244                                  73
#
#    Number of Sample-Test Data (GDSC)   Number of Feature  Name of Features  \
# 0                                  67                  2  {NUAK1, METTL7A}
#
#    TPs (True Positives)  TNs (True Negatives)  FPs (False Positives)  \
# 0                     9                     2                     56
#
#    FNs (False Negatives)  Precision    Recall  F1 Score  Accuracy       AUC
# 0                      0   0.884271  0.164179  0.090386  0.164179  0.517241
# breast
# 17-AAG
#   Histology    Drug  Number of Sample-Train Data (CCLE)  \
# 0    breast  17-AAG                                 279
#
#    Number of Sample-Test Data (GDSC)   Number of Feature Name of Features  \
# 0                                  44                  2     {IDH1, LEO1}
#
#    TPs (True Positives)  TNs (True Negatives)  FPs (False Positives)  \
# 0                     0                    41                      0
#
#    FNs (False Negatives)  Precision    Recall  F1 Score  Accuracy  AUC
# 0                      3   0.868285  0.931818   0.89893  0.931818  0.5
# breast
# PD-0325901
#   Histology        Drug  Number of Sample-Train Data (CCLE)  \
# 0    breast  PD-0325901                                 136
#
#    Number of Sample-Test Data (GDSC)   Number of Feature Name of Features  \
# 0                                  43                  1         {POLR1D}
#
#    TPs (True Positives)  TNs (True Negatives)  FPs (False Positives)  \
# 0                     0                    33                      8
#
#    FNs (False Negatives)  Precision    Recall  F1 Score  Accuracy       AUC
# 0                      2   0.899003  0.767442  0.828029  0.767442  0.402439
# digestive_system
# AZD6244
#           Histology     Drug  Number of Sample-Train Data (CCLE)  \
# 0  digestive_system  AZD6244                                  73
#
#    Number of Sample-Test Data (GDSC)   Number of Feature  \
# 0                                  40                  4
#
#                     Name of Features  TPs (True Positives)  \
# 0  {METTL7A, ARHGEF6, ZBTB8B, ASAP3}                     5
#
#    TNs (True Negatives)  FPs (False Positives)  FNs (False Negatives)  \
# 0                    15                     18                      2
#
#    Precision  Recall  F1 Score  Accuracy       AUC
# 0   0.765985     0.5  0.553333       0.5  0.584416
# digestive_system
# 17-AAG
#           Histology    Drug  Number of Sample-Train Data (CCLE)  \
# 0  digestive_system  17-AAG                                 279
#
#    Number of Sample-Test Data (GDSC)   Number of Feature    Name of Features  \
# 0                                  43                  3  {BPTF, PEX1, IDH1}
#
#    TPs (True Positives)  TNs (True Negatives)  FPs (False Positives)  \
# 0                     0                    38                      0
#
#    FNs (False Negatives)  Precision    Recall  F1 Score  Accuracy  AUC
# 0                      5   0.780963  0.883721   0.82917  0.883721  0.5
# digestive_system
# PD-0325901
#           Histology        Drug  Number of Sample-Train Data (CCLE)  \
# 0  digestive_system  PD-0325901                                 136
#
#    Number of Sample-Test Data (GDSC)   Number of Feature Name of Features  \
# 0                                  42                  2  {POLR1D, KCNQ1}
#
#    TPs (True Positives)  TNs (True Negatives)  FPs (False Positives)  \
# 0                     0                    37                      1
#
#    FNs (False Negatives)  Precision    Recall  F1 Score  Accuracy       AUC
# 0                      4   0.816492  0.880952  0.847498  0.880952  0.486842
# kidney
# PD-0325901
#   Histology        Drug  Number of Sample-Train Data (CCLE)  \
# 0    kidney  PD-0325901                                 137
#
#    Number of Sample-Test Data (GDSC)   Number of Feature Name of Features  \
# 0                                  24                  2  {POLR1D, KCNE3}
#
#    TPs (True Positives)  TNs (True Negatives)  FPs (False Positives)  \
# 0                     1                    19                      2
#
#    FNs (False Negatives)  Precision    Recall  F1 Score  Accuracy       AUC
# 0                      2   0.833333  0.833333  0.833333  0.833333  0.619048
# large_intestine
# 17-AAG
#          Histology    Drug  Number of Sample-Train Data (CCLE)  \
# 0  large_intestine  17-AAG                                 279
#
#    Number of Sample-Test Data (GDSC)   Number of Feature Name of Features  \
# 0                                  40                  1           {IDH1}
#
#    TPs (True Positives)  TNs (True Negatives)  FPs (False Positives)  \
# 0                     0                    37                      2
#
#    FNs (False Negatives)  Precision  Recall  F1 Score  Accuracy       AUC
# 0                      1   0.949342   0.925  0.937013     0.925  0.474359
# large_intestine
# PD-0325901
#          Histology        Drug  Number of Sample-Train Data (CCLE)  \
# 0  large_intestine  PD-0325901                                 136
#
#    Number of Sample-Test Data (GDSC)   Number of Feature  \
# 0                                  40                  4
#
#                  Name of Features  TPs (True Positives)  TNs (True Negatives)  \
# 0  {POLR1D, OGFRL1, TENT2, KCNQ1}                     0                    22
#
#    FPs (False Positives)  FNs (False Negatives)  Precision  Recall  F1 Score  \
# 0                      1                     17   0.324359    0.55  0.408065
#
#    Accuracy       AUC
# 0      0.55  0.478261
# leukemia
# Crizotinib
#   Histology        Drug  Number of Sample-Train Data (CCLE)  \
# 0  leukemia  Crizotinib                                  49
#
#    Number of Sample-Test Data (GDSC)   Number of Feature Name of Features  \
# 0                                  68                  1          {PPIL6}
#
#    TPs (True Positives)  TNs (True Negatives)  FPs (False Positives)  \
# 0                    12                    22                     26
#
#    FNs (False Negatives)  Precision  Recall  F1 Score  Accuracy       AUC
# 0                      8   0.610526     0.5  0.519894       0.5  0.529167
# leukemia
# Nilotinib
#   Histology       Drug  Number of Sample-Train Data (CCLE)  \
# 0  leukemia  Nilotinib                                  31
#
#    Number of Sample-Test Data (GDSC)   Number of Feature Name of Features  \
# 0                                  72                  1       {SLC38A11}
#
#    TPs (True Positives)  TNs (True Negatives)  FPs (False Positives)  \
# 0                     4                    35                      5
#
#    FNs (False Negatives)  Precision    Recall  F1 Score  Accuracy  AUC
# 0                     28   0.506173  0.541667  0.464283  0.541667  0.5
# leukemia
# 17-AAG
#   Histology    Drug  Number of Sample-Train Data (CCLE)  \
# 0  leukemia  17-AAG                                  67
#
#    Number of Sample-Test Data (GDSC)   Number of Feature Name of Features  \
# 0                                  73                  1          {SIKE1}
#
#    TPs (True Positives)  TNs (True Negatives)  FPs (False Positives)  \
# 0                     0                    15                     58
#
#    FNs (False Negatives)  Precision    Recall  F1 Score  Accuracy  AUC
# 0                      0        1.0  0.205479  0.340909  0.205479  NaN
# leukemia
# Lapatinib
#   Histology       Drug  Number of Sample-Train Data (CCLE)  \
# 0  leukemia  Lapatinib                                  28
#
#    Number of Sample-Test Data (GDSC)   Number of Feature Name of Features  \
# 0                                  68                  1          {PPIL6}
#
#    TPs (True Positives)  TNs (True Negatives)  FPs (False Positives)  \
# 0                     1                    17                     49
#
#    FNs (False Negatives)  Precision    Recall  F1 Score  Accuracy       AUC
# 0                      1   0.917255  0.264706  0.393988  0.264706  0.378788
# leukemia
# Paclitaxel
#   Histology        Drug  Number of Sample-Train Data (CCLE)  \
# 0  leukemia  Paclitaxel                                  66
#
#    Number of Sample-Test Data (GDSC)   Number of Feature Name of Features  \
# 0                                  68                  1           {GLMN}
#
#    TPs (True Positives)  TNs (True Negatives)  FPs (False Positives)  \
# 0                     0                    36                     32
#
#    FNs (False Negatives)  Precision    Recall  F1 Score  Accuracy  AUC
# 0                      0        1.0  0.529412  0.692308  0.529412  NaN
# leukemia
# PD-0332991
#   Histology        Drug  Number of Sample-Train Data (CCLE)  \
# 0  leukemia  PD-0332991                                  41
#
#    Number of Sample-Test Data (GDSC)   Number of Feature Name of Features  \
# 0                                  73                  1          {UTP11}
#
#    TPs (True Positives)  TNs (True Negatives)  FPs (False Positives)  \
# 0                    17                     4                     48
#
#    FNs (False Negatives)  Precision    Recall  F1 Score  Accuracy       AUC
# 0                      4   0.431401  0.287671  0.208708  0.287671  0.443223
# leukemia
# PD-0325901
#   Histology        Drug  Number of Sample-Train Data (CCLE)  \
# 0  leukemia  PD-0325901                                  21
#
#    Number of Sample-Test Data (GDSC)   Number of Feature Name of Features  \
# 0                                  73                  1          {ICAM1}
#
#    TPs (True Positives)  TNs (True Negatives)  FPs (False Positives)  \
# 0                    12                    21                     37
#
#    FNs (False Negatives)  Precision    Recall  F1 Score  Accuracy       AUC
# 0                      3   0.745527  0.452055  0.484004  0.452055  0.581034
# lung
# AZD6244
#   Histology     Drug  Number of Sample-Train Data (CCLE)  \
# 0      lung  AZD6244                                  74
#
#    Number of Sample-Test Data (GDSC)   Number of Feature  \
# 0                                 147                  4
#
#            Name of Features  TPs (True Positives)  TNs (True Negatives)  \
# 0  {PEMT, GJB6, AMPH, SYF2}                     8                    48
#
#    FPs (False Positives)  FNs (False Negatives)  Precision    Recall  \
# 0                     87                      4   0.854598  0.380952
#
#    F1 Score  Accuracy       AUC
# 0  0.483668  0.380952  0.511111
# lung
# Crizotinib
#   Histology        Drug  Number of Sample-Train Data (CCLE)  \
# 0      lung  Crizotinib                                  94
#
#    Number of Sample-Test Data (GDSC)   Number of Feature Name of Features  \
# 0                                  65                  1         {CFAP58}
#
#    TPs (True Positives)  TNs (True Negatives)  FPs (False Positives)  \
# 0                     1                     3                     61
#
#    FNs (False Negatives)  Precision    Recall  F1 Score  Accuracy       AUC
# 0                      0   0.984864  0.061538  0.088663  0.061538  0.523438
# lung
# Sorafenib
#   Histology       Drug  Number of Sample-Train Data (CCLE)  \
# 0      lung  Sorafenib                                  66
#
#    Number of Sample-Test Data (GDSC)   Number of Feature Name of Features  \
# 0                                  65                  2  {AKR1C2, TUSC3}
#
#    TPs (True Positives)  TNs (True Negatives)  FPs (False Positives)  \
# 0                     1                    43                     20
#
#    FNs (False Negatives)  Precision    Recall  F1 Score  Accuracy      AUC
# 0                      1   0.948668  0.676923  0.781683  0.676923  0.59127
# lung
# 17-AAG
#   Histology    Drug  Number of Sample-Train Data (CCLE)  \
# 0      lung  17-AAG                                 287
#
#    Number of Sample-Test Data (GDSC)   Number of Feature Name of Features  \
# 0                                 153                  2  {EPB41L4B, NVL}
#
#    TPs (True Positives)  TNs (True Negatives)  FPs (False Positives)  \
# 0                     1                   105                     40
#
#    FNs (False Negatives)  Precision   Recall  F1 Score  Accuracy       AUC
# 0                      7   0.889756  0.69281   0.77653   0.69281  0.424569
# lung
# Lapatinib
#   Histology       Drug  Number of Sample-Train Data (CCLE)  \
# 0      lung  Lapatinib                                 100
#
#    Number of Sample-Test Data (GDSC)   Number of Feature Name of Features  \
# 0                                  64                  2    {PSD4, TMUB2}
#
#    TPs (True Positives)  TNs (True Negatives)  FPs (False Positives)  \
# 0                     5                    22                     35
#
#    FNs (False Negatives)  Precision    Recall  F1 Score  Accuracy       AUC
# 0                      2   0.830078  0.421875  0.507068  0.421875  0.550125
# lung
# Erlotinib
#   Histology       Drug  Number of Sample-Train Data (CCLE)  \
# 0      lung  Erlotinib                                  66
#
#    Number of Sample-Test Data (GDSC)   Number of Feature  \
# 0                                  56                  8
#
#                                     Name of Features  TPs (True Positives)  \
# 0  {AKAP5, GSG1, CD6, GDA, S100A14, IKBIP, TBXA2R...                     2
#
#    TNs (True Negatives)  FPs (False Positives)  FNs (False Negatives)  \
# 0                    36                     12                      6
#
#    Precision    Recall  F1 Score  Accuracy  AUC
# 0   0.755102  0.678571  0.711688  0.678571  0.5
# lung
# PD-0325901
#   Histology        Drug  Number of Sample-Train Data (CCLE)  \
# 0      lung  PD-0325901                                 139
#
#    Number of Sample-Test Data (GDSC)   Number of Feature  \
# 0                                 153                  7
#
#                                     Name of Features  TPs (True Positives)  \
# 0  {GNA14, POLR1D, FHDC1, TRAF5, SIT1, S100A5, TR...                     2
#
#    TNs (True Negatives)  FPs (False Positives)  FNs (False Negatives)  \
# 0                   130                      9                     12
#
#    Precision    Recall  F1 Score  Accuracy       AUC
# 0   0.848359  0.862745  0.855242  0.862745  0.539054
# lymphoma
# NVP-TAE684
#   Histology        Drug  Number of Sample-Train Data (CCLE)  \
# 0  lymphoma  NVP-TAE684                                  36
#
#    Number of Sample-Test Data (GDSC)   Number of Feature   Name of Features  \
# 0                                  58                  2  {GABPB2, IGF2BP1}
#
#    TPs (True Positives)  TNs (True Negatives)  FPs (False Positives)  \
# 0                     0                    51                      0
#
#    FNs (False Negatives)  Precision   Recall  F1 Score  Accuracy  AUC
# 0                      7   0.773187  0.87931  0.822841   0.87931  0.5
# lymphoma
# Crizotinib
#   Histology        Drug  Number of Sample-Train Data (CCLE)  \
# 0  lymphoma  Crizotinib                                  36
#
#    Number of Sample-Test Data (GDSC)   Number of Feature Name of Features  \
# 0                                  58                  1          {PPIL6}
#
#    TPs (True Positives)  TNs (True Negatives)  FPs (False Positives)  \
# 0                     0                    38                      7
#
#    FNs (False Negatives)  Precision    Recall  F1 Score  Accuracy       AUC
# 0                     13   0.578093  0.655172  0.614224  0.655172  0.422222
# lymphoma
# Paclitaxel
#   Histology        Drug  Number of Sample-Train Data (CCLE)  \
# 0  lymphoma  Paclitaxel                                  51
#
#    Number of Sample-Test Data (GDSC)   Number of Feature Name of Features  \
# 0                                  57                  1           {ALAD}
#
#    TPs (True Positives)  TNs (True Negatives)  FPs (False Positives)  \
# 0                     3                     5                     49
#
#    FNs (False Negatives)  Precision    Recall  F1 Score  Accuracy       AUC
# 0                      0   0.950405  0.140351  0.166313  0.140351  0.546296
# lymphoma
# PD-0332991
#   Histology        Drug  Number of Sample-Train Data (CCLE)  \
# 0  lymphoma  PD-0332991                                  33
#
#    Number of Sample-Test Data (GDSC)   Number of Feature Name of Features  \
# 0                                  63                  1         {RIPOR2}
#
#    TPs (True Positives)  TNs (True Negatives)  FPs (False Positives)  \
# 0                     0                    59                      0
#
#    FNs (False Negatives)  Precision    Recall  F1 Score  Accuracy  AUC
# 0                      4   0.877047  0.936508  0.905803  0.936508  0.5
# nervous_system
# Paclitaxel
#         Histology        Drug  Number of Sample-Train Data (CCLE)  \
# 0  nervous_system  Paclitaxel                                  25
#
#    Number of Sample-Test Data (GDSC)   Number of Feature  Name of Features  \
# 0                                  25                  2  {LDLRAP1, RPL11}
#
#    TPs (True Positives)  TNs (True Negatives)  FPs (False Positives)  \
# 0                     0                    21                      2
#
#    FNs (False Negatives)  Precision  Recall  F1 Score  Accuracy       AUC
# 0                      2       0.84    0.84      0.84      0.84  0.456522
# pancreas
# 17-AAG
#   Histology    Drug  Number of Sample-Train Data (CCLE)  \
# 0  pancreas  17-AAG                                 279
#
#    Number of Sample-Test Data (GDSC)   Number of Feature Name of Features  \
# 0                                  24                  2     {IDH1, LEO1}
#
#    TPs (True Positives)  TNs (True Negatives)  FPs (False Positives)  \
# 0                     0                    22                      0
#
#    FNs (False Negatives)  Precision    Recall  F1 Score  Accuracy  AUC
# 0                      2   0.840278  0.916667  0.876812  0.916667  0.5
# pancreas
# PD-0325901
#   Histology        Drug  Number of Sample-Train Data (CCLE)  \
# 0  pancreas  PD-0325901                                 136
#
#    Number of Sample-Test Data (GDSC)   Number of Feature Name of Features  \
# 0                                  23                  1         {POLR1D}
#
#    TPs (True Positives)  TNs (True Negatives)  FPs (False Positives)  \
# 0                     2                     6                      6
#
#    FNs (False Negatives)  Precision    Recall  F1 Score  Accuracy       AUC
# 0                      9   0.328261  0.347826  0.332571  0.347826  0.340909
# skin
# 17-AAG
#   Histology    Drug  Number of Sample-Train Data (CCLE)  \
# 0      skin  17-AAG                                  32
#
#    Number of Sample-Test Data (GDSC)   Number of Feature Name of Features  \
# 0                                  45                  1           {MAOB}
#
#    TPs (True Positives)  TNs (True Negatives)  FPs (False Positives)  \
# 0                     6                     5                     32
#
#    FNs (False Negatives)  Precision    Recall  F1 Score  Accuracy       AUC
# 0                      2   0.615372  0.244444  0.233245  0.244444  0.442568
# skin
# PD-0325901
#   Histology        Drug  Number of Sample-Train Data (CCLE)  \
# 0      skin  PD-0325901                                  34
#
#    Number of Sample-Test Data (GDSC)   Number of Feature  \
# 0                                  43                  3
#
#         Name of Features  TPs (True Positives)  TNs (True Negatives)  \
# 0  {MN1, RNF144A, SHTN1}                    17                     6
#
#    FPs (False Positives)  FNs (False Negatives)  Precision    Recall  \
# 0                      7                     13   0.589657  0.534884
#
#    F1 Score  Accuracy       AUC
# 0  0.552649  0.534884  0.514103
# urogenital_system
# Nilotinib
#            Histology       Drug  Number of Sample-Train Data (CCLE)  \
# 0  urogenital_system  Nilotinib                                  62
#
#    Number of Sample-Test Data (GDSC)   Number of Feature Name of Features  \
# 0                                  71                  1         {MRPL41}
#
#    TPs (True Positives)  TNs (True Negatives)  FPs (False Positives)  \
# 0                     2                    17                     49
#
#    FNs (False Negatives)  Precision    Recall  F1 Score  Accuracy       AUC
# 0                      3   0.792903  0.267606  0.372538  0.267606  0.328788
# urogenital_system
# PD-0325901
#            Histology        Drug  Number of Sample-Train Data (CCLE)  \
# 0  urogenital_system  PD-0325901                                 137
#
#    Number of Sample-Test Data (GDSC)   Number of Feature Name of Features  \
# 0                                  91                  1         {POLR1D}
#
#    TPs (True Positives)  TNs (True Negatives)  FPs (False Positives)  \
# 0                     4                    60                     16
#
#    FNs (False Negatives)  Precision    Recall  F1 Score  Accuracy      AUC
# 0                     11    0.73874  0.703297  0.719444  0.703297  0.52807

# %%
All_histologies_drugs_result_new_rf = All_histologies_drugs_result.sort_values(by='AUC', ascending=False)

# %%
All_histologies_drugs_result_new_rf.to_excel(os.path.join(output_dir_gdsc, "All RESULT_RF_Classification .xlsx"), index=False)

# %%
confusion
# Out:
# array([[60, 16],
#        [11,  4]], dtype=int64)
